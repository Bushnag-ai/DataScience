# %%
pip install pybullet
# Out:
# Collecting pybullet
#   Downloading pybullet-3.2.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (90.8 MB)
#      |████████████████████████████████| 90.8 MB 289 bytes/s
# Installing collected packages: pybullet
# Successfully installed pybullet-3.2.1

# %%
import os
import time
import random

import numpy as np
import matplotlib.pyplot as plt

import gym
import pybullet_envs

import torch
import torch.nn as nn
import torch.nn.functional as F

from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('GPU on:', True if torch.cuda.is_available() else False, '| Device:',DEVICE)
# Out:
# GPU on: True | Device: cuda

# %%
class ReplayBuffer(object):
    def __init__(self, max_size=1e6):
        self.storage = []
        self.max_size = max_size
        self.ptr = 0
    
    def add(self, transition):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = transition
            self.ptr = (self.ptr+1) % self.max_size
        else:
            self.storage.append(transition) 
    
    def sample(self, batch_size):
        sample_data = np.random.randint(0, len(self.storage), size=batch_size)

        states_ = []
        next_states_ = [] 
        actions_ = []
        rewards_ = []
        dones_= []
        for i in sample_data:
            state, next_state, action, reward, done = self.storage[i]
            states_.append(state)
            next_states_.append(next_state)
            actions_.append(action)
            rewards_.append(reward)
            dones_.append(done)
        
        return np.array(states_), np.array(next_states_), np.array(actions_), np.array(rewards_).reshape(-1,1), np.array(dones_).reshape(-1,1)

# %%
class Actor(nn.Module):
    def __init__(self, input, action, cut):#action is the number outputs | output is the number of actions
        super(Actor,self).__init__()
        self.fully01 = nn.Linear(input, 400)
        self.fully02 = nn.Linear(400,300)
        self.last = nn.Linear(300, action)
        self.cut = cut

    def forward(self, x):
        x = F.relu(self.fully01(x))
        x = F.relu(self.fully02(x))
        return self.cut * torch.tanh(self.last(x))#the cut to adjust to the output levels. higher or lower that -1,1

# %%
#since we need two pair of critics, im making both on the same class.
#the name of the class should be DoubleCritic,PairCritic..etc
class Critic(nn.Module):
    def __init__(self, input, action):
        super(Critic, self).__init__()
        #first
        self.fully01 = nn.Linear(input+action, 400)
        self.fully02 = nn.Linear(400,300)
        self.fully03 = nn.Linear(300, 1)

        #second
        self.fully11 = nn.Linear(input+action, 400)
        self.fully22 = nn.Linear(400,300)
        self.fully33 = nn.Linear(300, 1)

    def forward(self, x, u):
        xu = torch.cat([x,u], 1)
        #first
        x = F.relu(self.fully01(xu))
        x = F.relu(self.fully02(x))
        x = self.fully03(x)
        #Second
        y = F.relu(self.fully11(xu))
        y = F.relu(self.fully22(y))
        y = self.fully33(y)
        return x, y

    def Q1(self, x, u):
        xu = torch.cat([x,u], 1)
        x = F.relu(self.fully01(xu))
        x = F.relu(self.fully02(x))
        x = self.fully03(x)
        return x

# %%
#training
class TD3(object):
    def __init__(self, state_dim, action_dim, max_action):
        # actors
        self.Actor = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target.load_state_dict(self.Actor.state_dict())

        # actor optimizer
        self.Actor_optimizer = torch.optim.Adam(self.Actor.parameters())

        ## Critic 
        self.Critic = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_Target = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_Target.load_state_dict(self.Critic.state_dict())

        ## Critic optimizer
        self.Critic_optimizer = torch.optim.Adam(self.Critic.parameters())

        ### Max_Action is the cut/clip
        self.max_action =  max_action

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1,-1)).to(DEVICE)
        return self.Actor(state).cpu().data.numpy().flatten()
        #return self.Actor(state).data.numpy().flatten()

    def save(self, filename, directory):
        torch.save(self.Actor.state_dict(),'%s/%s_Actor.pth' % (directory,filename))
        torch.save(self.Critic.state_dict(),'%s/%s_Critic.pth' % (directory,filename))

    def load(self, filename, directory):
        self.Actor.load_state_dict(torch.load('%s/%s_Actor.pth' % (directory,filename)))
        self.Critic.load_state_dict(torch.load('%s/%s_Critic.pth' % (directory,filename)))
    
    def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
        for i in range(iterations):
            states_, next_states_, actions_, rewards_, dones_ = replay_buffer.sample(batch_size)

            state = torch.Tensor(states_).to(DEVICE)
            next_state = torch.Tensor(next_states_).to(DEVICE)
            action = torch.Tensor(actions_).to(DEVICE)
            reward = torch.Tensor(rewards_).to(DEVICE)
            done = torch.Tensor(dones_).to(DEVICE)

            next_action = self.Actor_Target(next_state)

            noise = torch.Tensor(actions_).data.normal_(0, policy_noise).to(DEVICE)
            noise = noise.clamp(-noise_clip,noise_clip)
            next_action = (next_action+noise).clamp(-self.max_action, self.max_action)

            Target_Q1, Target_Q2 = self.Critic_Target(next_state, next_action)
            
            #when episode is over 1, not over 0. 
            # we detached because adding the reward which is the output 
            #of nn to the computaional graph would not be what we want.
            Target_Q = torch.min(Target_Q1, Target_Q2)
            Target_Q = reward + (discount * Target_Q * (1 - done)).detach()
          
            Current_Q1, Current_Q2 = self.Critic(state, action)
            critic_loss = F.mse_loss(Current_Q1,Target_Q) + F.mse_loss(Current_Q2, Target_Q)

            self.Critic_optimizer.zero_grad()
            critic_loss.backward()
            self.Critic_optimizer.step()

            if not i % policy_freq:
                actor_loss = -self.Critic.Q1(state, self.Actor(state)).mean()
                self.Actor_optimizer.zero_grad()
                actor_loss.backward()
                self.Actor_optimizer.step()

                for param, target_param in zip(self.Actor.parameters(), self.Actor_Target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)
                
                
                for param, target_param in zip(self.Critic.parameters(), self.Critic_Target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)

# %%
def evaluate_policy(policy, episodes=10):
    avg_awards = 0
    for _ in range(episodes):
        obs = env.reset()
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done, _ = env.step(action)
            avg_awards += reward
    avg_awards /= episodes
    print(f"Average award over {episodes} is:",avg_awards)
    return avg_awards

# %%
#parameters
env_name = 'Walker2DBulletEnv-v0'
seed = 0
start_timesteps = 1e4
eval_freq = 5e3
max_timesteps= 5e5

save_model = True
expi_noise = 0.1
batch_size = 100
discount = 0.99
tau = 0.005

policy_noise = 0.2
noise_clip = 0.5
policy_freq = 2

# %%
env = gym.make(env_name)

# %%
file_name = f"TD3--{env_name}--seed({seed})"
print(file_name)
# Out:
# TD3--Walker2DBulletEnv-v0--seed(0)

# %%
if not os.path.exists('./results'):
    os.makedirs('./results')
if save_model and not os.path.exists('./pytorch_models'):
    os.makedirs('./pytorch_models')

# %%
#setting env
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %%
policy = TD3(state_dim, action_dim, max_action)

# %%
replay_buffer = ReplayBuffer()

# %%
evaluation = [evaluate_policy(policy)]
# Out:
# Average award over 10 is: 264.9672989036841

# %%
def mkdir(base, name):
    path = os.path.join(base,name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
    
work_dir = mkdir('exp','brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_step = env._max_episode_steps
save_env_vid = False
if save_env_vid:
    env = wrappers.Monitor(env, monitor_dir, force=True)
    env.reset()

# %%
#initializing the variables
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %%
while total_timesteps < max_timesteps:
    if done:
        if total_timesteps != 0:
            print(f'Total timesteps:{total_timesteps} - Episode num:{episode_num} - Reward:{episode_reward}')
            policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
        
        if timesteps_since_eval >= eval_freq:
            timesteps_since_eval %=  eval_freq
            evaluation.append(evaluate_policy(policy))
            policy.save(file_name, directory='./pytorch_models')
            np.save('./results/%s'%(file_name), evaluation)

        obs = env.reset()
        done = False

        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    #Before 10000 timesteps,we play Random actions.
    if total_timesteps < start_timesteps:
        action = env.action_space.sample()
    else:#after 10000 we switch to the policy/model/agent
        action = policy.select_action(np.array(obs))
        if expi_noise != 0:
            action = (action + np.random.normal(0, expi_noise, size=env.action_space.shape[0])).clip(env.action_space.low,env.action_space.high)

    new_obs, reward, done, _ = env.step(action)

    done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)

    episode_reward += reward
    
    replay_buffer.add((obs, new_obs, action, reward, done_bool))

    obs = new_obs
    episode_timesteps += 1
    total_timesteps += 1
    timesteps_since_eval += 1

evaluation.append(evaluate_policy(policy))
if save_model:
    policy.save('%s'% (file_name), directory='./pytorch_models')
np.save("./results/%s" % (file_name),evaluation)
# Out:
# Total timesteps:11 - Episode num:1 - Reward:14.342351449678246
# Total timesteps:31 - Episode num:2 - Reward:20.777396590379066
# Total timesteps:48 - Episode num:3 - Reward:20.514735043872495
# Total timesteps:55 - Episode num:4 - Reward:10.83502477268048
# Total timesteps:71 - Episode num:5 - Reward:17.43650487842533
# Total timesteps:110 - Episode num:6 - Reward:35.59045141547685
# Total timesteps:120 - Episode num:7 - Reward:15.484733266291732
# Total timesteps:141 - Episode num:8 - Reward:21.129919926942964
# Total timesteps:154 - Episode num:9 - Reward:16.60799936141848
# Total timesteps:163 - Episode num:10 - Reward:12.953738050516403
# Total timesteps:181 - Episode num:11 - Reward:20.30876482272433
# Total timesteps:190 - Episode num:12 - Reward:12.539863156058708
# Total timesteps:203 - Episode num:13 - Reward:16.99671558473783
# Total timesteps:216 - Episode num:14 - Reward:17.49615300779551
# Total timesteps:226 - Episode num:15 - Reward:14.988500758878942
# Total timesteps:236 - Episode num:16 - Reward:12.637848501786356
# Total timesteps:256 - Episode num:17 - Reward:21.005904548405667
# Total timesteps:284 - Episode num:18 - Reward:22.855432244967957
# Total timesteps:295 - Episode num:19 - Reward:14.57070599636354
# Total timesteps:316 - Episode num:20 - Reward:18.385610860692395
# Total timesteps:328 - Episode num:21 - Reward:14.531998926417145
# Total timesteps:345 - Episode num:22 - Reward:18.089736007302417
# Total timesteps:364 - Episode num:23 - Reward:19.221056429600868
# Total timesteps:376 - Episode num:24 - Reward:15.381882259839038
# Total timesteps:388 - Episode num:25 - Reward:15.461289752657466
# Total timesteps:399 - Episode num:26 - Reward:14.208728214727309
# Total timesteps:406 - Episode num:27 - Reward:12.340456013823859
# Total timesteps:418 - Episode num:28 - Reward:16.78383771077788
# Total timesteps:430 - Episode num:29 - Reward:15.0410243112492
# Total timesteps:439 - Episode num:30 - Reward:14.689309612881335
# Total timesteps:456 - Episode num:31 - Reward:18.142141770262967
# Total timesteps:473 - Episode num:32 - Reward:17.8768946269367
# Total timesteps:486 - Episode num:33 - Reward:15.639260086209108
# Total timesteps:495 - Episode num:34 - Reward:13.408048709966533
# Total timesteps:505 - Episode num:35 - Reward:14.2854911715287
# Total timesteps:522 - Episode num:36 - Reward:18.400320878099595
# Total timesteps:530 - Episode num:37 - Reward:13.311849211379013
# Total timesteps:540 - Episode num:38 - Reward:13.577043815131765
# Total timesteps:549 - Episode num:39 - Reward:13.709024102211696
# Total timesteps:563 - Episode num:40 - Reward:15.283726638081133
# Total timesteps:577 - Episode num:41 - Reward:16.887923304348078
# Total timesteps:616 - Episode num:42 - Reward:31.286326646452654
# Total timesteps:631 - Episode num:43 - Reward:15.220856256636033
# Total timesteps:638 - Episode num:44 - Reward:11.904699899967818
# Total timesteps:649 - Episode num:45 - Reward:16.06433876611554
# Total timesteps:670 - Episode num:46 - Reward:22.84785707940609
# Total timesteps:694 - Episode num:47 - Reward:21.408207806119755
# Total timesteps:708 - Episode num:48 - Reward:17.414473808054755
# Total timesteps:717 - Episode num:49 - Reward:14.488322895027522
# Total timesteps:733 - Episode num:50 - Reward:17.26821280108852
# Total timesteps:743 - Episode num:51 - Reward:12.801133176773147
# Total timesteps:753 - Episode num:52 - Reward:14.47058460851258
# Total timesteps:764 - Episode num:53 - Reward:14.553881892502249
# Total timesteps:781 - Episode num:54 - Reward:17.73940252035245
# Total timesteps:796 - Episode num:55 - Reward:15.566767139472356
# Total timesteps:818 - Episode num:56 - Reward:21.282495636037492
# Total timesteps:835 - Episode num:57 - Reward:18.988927895503
# Total timesteps:851 - Episode num:58 - Reward:17.99280517025909
# Total timesteps:875 - Episode num:59 - Reward:23.06626782969688
# Total timesteps:885 - Episode num:60 - Reward:15.766379569531999
# Total timesteps:903 - Episode num:61 - Reward:17.202751360945697
# Total timesteps:927 - Episode num:62 - Reward:21.527289679113895
# Total timesteps:940 - Episode num:63 - Reward:16.094724227441475
# Total timesteps:953 - Episode num:64 - Reward:17.05789524832362
# Total timesteps:966 - Episode num:65 - Reward:15.582181148251403
# Total timesteps:980 - Episode num:66 - Reward:14.832351194586954
# Total timesteps:993 - Episode num:67 - Reward:15.958179062683481
# Total timesteps:1014 - Episode num:68 - Reward:23.444779931240195
# Total timesteps:1029 - Episode num:69 - Reward:18.65881733169663
# Total timesteps:1049 - Episode num:70 - Reward:19.53434439699922
# Total timesteps:1059 - Episode num:71 - Reward:12.458534262720786
# Total timesteps:1087 - Episode num:72 - Reward:25.38715528322937
# Total timesteps:1105 - Episode num:73 - Reward:17.71638108358893
# Total timesteps:1118 - Episode num:74 - Reward:16.481347945431477
# Total timesteps:1128 - Episode num:75 - Reward:14.805972845821813
# Total timesteps:1141 - Episode num:76 - Reward:16.46835587957612
# Total timesteps:1162 - Episode num:77 - Reward:21.76570681880548
# Total timesteps:1174 - Episode num:78 - Reward:16.66676559290354
# Total timesteps:1191 - Episode num:79 - Reward:17.893920109845933
# Total timesteps:1201 - Episode num:80 - Reward:14.644939592304583
# Total timesteps:1210 - Episode num:81 - Reward:12.575384816579755
# Total timesteps:1223 - Episode num:82 - Reward:14.963339334251941
# Total timesteps:1245 - Episode num:83 - Reward:17.69905193191371
# Total timesteps:1264 - Episode num:84 - Reward:21.995445647767333
# Total timesteps:1279 - Episode num:85 - Reward:18.617511667308282
# Total timesteps:1290 - Episode num:86 - Reward:13.542454296232608
# Total timesteps:1305 - Episode num:87 - Reward:18.95505968691723
# Total timesteps:1315 - Episode num:88 - Reward:12.997289275696675
# Total timesteps:1332 - Episode num:89 - Reward:19.92671386127622
# Total timesteps:1365 - Episode num:90 - Reward:26.973018248073643
# Total timesteps:1377 - Episode num:91 - Reward:16.94180098458164
# Total timesteps:1386 - Episode num:92 - Reward:13.042538248778145
# Total timesteps:1399 - Episode num:93 - Reward:17.97559963236563
# Total timesteps:1410 - Episode num:94 - Reward:15.50795366331731
# Total timesteps:1422 - Episode num:95 - Reward:14.078803444834193
# Total timesteps:1435 - Episode num:96 - Reward:14.803306824361789
# Total timesteps:1465 - Episode num:97 - Reward:27.173401355600795
# Total timesteps:1476 - Episode num:98 - Reward:15.815450828308531
# Total timesteps:1494 - Episode num:99 - Reward:16.18344330443215
# Total timesteps:1513 - Episode num:100 - Reward:19.748970912027286
# Total timesteps:1521 - Episode num:101 - Reward:11.205480659005115
# Total timesteps:1538 - Episode num:102 - Reward:17.806938270526015
# Total timesteps:1551 - Episode num:103 - Reward:16.621643735661927
# Total timesteps:1574 - Episode num:104 - Reward:25.62796763311344
# Total timesteps:1586 - Episode num:105 - Reward:14.010414396617854
# Total timesteps:1604 - Episode num:106 - Reward:20.86833877516037
# Total timesteps:1620 - Episode num:107 - Reward:19.40041541027749
# Total timesteps:3027 - Episode num:203 - Reward:14.247197884935305
# Total timesteps:3037 - Episode num:204 - Reward:14.490737689771047
# Total timesteps:3063 - Episode num:205 - Reward:22.03402879871719
# Total timesteps:3075 - Episode num:206 - Reward:15.73373521778267
# Total timesteps:3083 - Episode num:207 - Reward:12.55985679266887
# Total timesteps:3097 - Episode num:208 - Reward:15.731497662723994
# Total timesteps:3108 - Episode num:209 - Reward:13.383253243879878
# Total timesteps:3121 - Episode num:210 - Reward:15.668323701120974
# Total timesteps:3137 - Episode num:211 - Reward:16.64387418240076
# Total timesteps:3152 - Episode num:212 - Reward:15.763019822350179
# Total timesteps:3160 - Episode num:213 - Reward:12.136979917770077
# Total timesteps:3169 - Episode num:214 - Reward:13.78679993677215
# Total timesteps:3183 - Episode num:215 - Reward:16.067447095150417
# Total timesteps:3200 - Episode num:216 - Reward:18.184143384174966
# Total timesteps:3218 - Episode num:217 - Reward:18.26089378756587
# Total timesteps:3234 - Episode num:218 - Reward:17.2151584989464
# Total timesteps:3247 - Episode num:219 - Reward:16.85550941891124
# Total timesteps:3268 - Episode num:220 - Reward:21.758157780389592
# Total timesteps:3288 - Episode num:221 - Reward:21.60669625399023
# Total timesteps:3307 - Episode num:222 - Reward:15.424148566239454
# Total timesteps:3325 - Episode num:223 - Reward:21.969909605087015
# Total timesteps:3345 - Episode num:224 - Reward:19.810884859920765
# Total timesteps:3358 - Episode num:225 - Reward:15.540569181524916
# Total timesteps:3370 - Episode num:226 - Reward:14.997571046648954
# Total timesteps:3387 - Episode num:227 - Reward:20.00090773301345
# Total timesteps:3401 - Episode num:228 - Reward:16.060082125004556
# Total timesteps:3409 - Episode num:229 - Reward:13.086406014295061
# Total timesteps:3419 - Episode num:230 - Reward:14.077912741724866
# Total timesteps:3439 - Episode num:231 - Reward:18.45550800636993
# Total timesteps:3461 - Episode num:232 - Reward:20.880310073218425
# Total timesteps:3472 - Episode num:233 - Reward:14.779142817937824
# Total timesteps:3480 - Episode num:234 - Reward:13.03643630741135
# Total timesteps:3490 - Episode num:235 - Reward:14.137712378642753
# Total timesteps:3501 - Episode num:236 - Reward:14.528641312757097
# Total timesteps:3515 - Episode num:237 - Reward:17.455668157136827
# Total timesteps:3533 - Episode num:238 - Reward:18.56202958991926
# Total timesteps:3549 - Episode num:239 - Reward:18.076274584702333
# Total timesteps:3560 - Episode num:240 - Reward:16.30183987845812
# Total timesteps:3577 - Episode num:241 - Reward:17.25611677597335
# Total timesteps:3588 - Episode num:242 - Reward:15.514050828729523
# Total timesteps:3600 - Episode num:243 - Reward:14.45112501859112
# Total timesteps:3618 - Episode num:244 - Reward:18.418801841844108
# Total timesteps:3636 - Episode num:245 - Reward:16.051082350376234
# Total timesteps:3657 - Episode num:246 - Reward:20.50196967434458
# Total timesteps:3667 - Episode num:247 - Reward:14.100961137938429
# Total timesteps:3677 - Episode num:248 - Reward:14.421806647047923
# Total timesteps:3691 - Episode num:249 - Reward:18.69864026102732
# Total timesteps:3705 - Episode num:250 - Reward:16.51125942812505
# Total timesteps:3716 - Episode num:251 - Reward:16.169991505816867
# Total timesteps:3731 - Episode num:252 - Reward:15.74532390244567
# Total timesteps:3740 - Episode num:253 - Reward:12.19260741517937
# Total timesteps:3756 - Episode num:254 - Reward:18.75350352636451
# Total timesteps:3771 - Episode num:255 - Reward:17.157274118081844
# Total timesteps:3785 - Episode num:256 - Reward:18.27423382135312
# Total timesteps:3796 - Episode num:257 - Reward:13.845763750905464
# Total timesteps:3803 - Episode num:258 - Reward:12.665777249343227
# Total timesteps:3811 - Episode num:259 - Reward:14.110526155588742
# Total timesteps:3829 - Episode num:260 - Reward:18.84402181912592
# Total timesteps:3849 - Episode num:261 - Reward:16.454331437873773
# Total timesteps:3862 - Episode num:262 - Reward:15.8036851629251
# Total timesteps:3873 - Episode num:263 - Reward:14.894864889013114
# Total timesteps:3888 - Episode num:264 - Reward:17.949237192224246
# Total timesteps:3903 - Episode num:265 - Reward:16.918656195001677
# Total timesteps:3922 - Episode num:266 - Reward:18.25149100009148
# Total timesteps:3938 - Episode num:267 - Reward:15.391650105638835
# Total timesteps:3952 - Episode num:268 - Reward:16.5202673349937
# Total timesteps:3964 - Episode num:269 - Reward:15.472562750034559
# Total timesteps:3974 - Episode num:270 - Reward:13.332846513249388
# Total timesteps:3994 - Episode num:271 - Reward:20.471190583349376
# Total timesteps:4011 - Episode num:272 - Reward:16.71861249224894
# Total timesteps:4027 - Episode num:273 - Reward:19.03675401573419
# Total timesteps:4035 - Episode num:274 - Reward:11.365278784371913
# Total timesteps:4044 - Episode num:275 - Reward:12.238336374919163
# Total timesteps:4059 - Episode num:276 - Reward:18.964989634360244
# Total timesteps:4067 - Episode num:277 - Reward:14.955386267947324
# Total timesteps:4079 - Episode num:278 - Reward:14.399057639404784
# Total timesteps:4088 - Episode num:279 - Reward:13.00378196981328
# Total timesteps:4095 - Episode num:280 - Reward:11.654302458670283
# Total timesteps:4120 - Episode num:281 - Reward:16.96077701958711
# Total timesteps:4128 - Episode num:282 - Reward:11.287440907444399
# Total timesteps:4152 - Episode num:283 - Reward:20.86025715324358
# Total timesteps:4166 - Episode num:284 - Reward:14.632137707824585
# Total timesteps:4180 - Episode num:285 - Reward:16.785768608795475
# Total timesteps:4193 - Episode num:286 - Reward:14.051153699865973
# Total timesteps:4203 - Episode num:287 - Reward:14.974345831255778
# Total timesteps:4214 - Episode num:288 - Reward:15.761347852267498
# Total timesteps:4222 - Episode num:289 - Reward:11.952339732952533
# Total timesteps:4233 - Episode num:290 - Reward:14.329361132772464
# Total timesteps:4257 - Episode num:291 - Reward:19.585703633473894
# Total timesteps:4264 - Episode num:292 - Reward:12.384838872446561
# Total timesteps:4289 - Episode num:293 - Reward:25.6010633422673
# Total timesteps:4303 - Episode num:294 - Reward:17.823815953808662
# Total timesteps:4320 - Episode num:295 - Reward:19.539421224224494
# Total timesteps:4335 - Episode num:296 - Reward:17.44604446062003
# Total timesteps:4350 - Episode num:297 - Reward:17.39487818183698
# Total timesteps:4360 - Episode num:298 - Reward:12.894270279163903
# Total timesteps:4373 - Episode num:299 - Reward:17.635778879084686
# Total timesteps:4384 - Episode num:300 - Reward:13.593419252072637
# Total timesteps:4396 - Episode num:301 - Reward:15.217808011564193
# Total timesteps:4412 - Episode num:302 - Reward:17.752744257259472
# Total timesteps:4426 - Episode num:303 - Reward:17.58895796332217
# Total timesteps:4450 - Episode num:304 - Reward:21.762776761227
# Total timesteps:4459 - Episode num:305 - Reward:12.897912501824612
# Total timesteps:4469 - Episode num:306 - Reward:14.641164732028844
# Total timesteps:4485 - Episode num:307 - Reward:16.44021907876304
# Total timesteps:4502 - Episode num:308 - Reward:17.83855310520157
# Total timesteps:4513 - Episode num:309 - Reward:15.171033428190274
# Total timesteps:4524 - Episode num:310 - Reward:15.638677014115089
# Total timesteps:4538 - Episode num:311 - Reward:15.307518638529292
# Total timesteps:4556 - Episode num:312 - Reward:19.00433770820673
# Total timesteps:4568 - Episode num:313 - Reward:16.57851144663291
# Total timesteps:4581 - Episode num:314 - Reward:16.082344279765675
# Total timesteps:4588 - Episode num:315 - Reward:11.715291617297044
# Total timesteps:4606 - Episode num:316 - Reward:21.52550856643938
# Total timesteps:4625 - Episode num:317 - Reward:20.71721800975938
# Total timesteps:4643 - Episode num:318 - Reward:21.351840317220194
# Total timesteps:4653 - Episode num:319 - Reward:13.96911153980618
# Total timesteps:4673 - Episode num:320 - Reward:19.725782309172793
# Total timesteps:4681 - Episode num:321 - Reward:13.801549696724395
# Total timesteps:4696 - Episode num:322 - Reward:18.7877453052788
# Total timesteps:4704 - Episode num:323 - Reward:13.258813461418322
# Total timesteps:4714 - Episode num:324 - Reward:13.680483569994976
# Total timesteps:4729 - Episode num:325 - Reward:14.657823978117085
# Total timesteps:4744 - Episode num:326 - Reward:16.70846019106975
# Total timesteps:4751 - Episode num:327 - Reward:11.481332533949171
# Total timesteps:4765 - Episode num:328 - Reward:16.942525482607017
# Total timesteps:4775 - Episode num:329 - Reward:14.109177011190331
# Total timesteps:4793 - Episode num:330 - Reward:19.134722550587316
# Total timesteps:4804 - Episode num:331 - Reward:15.058787871881215
# Total timesteps:4823 - Episode num:332 - Reward:20.81668418720801
# Total timesteps:4850 - Episode num:333 - Reward:26.402966045303035
# Total timesteps:4860 - Episode num:334 - Reward:15.267119765933602
# Total timesteps:4876 - Episode num:335 - Reward:16.036195155829773
# Total timesteps:4886 - Episode num:336 - Reward:15.505638772988458
# Total timesteps:4900 - Episode num:337 - Reward:18.136587663985843
# Total timesteps:4909 - Episode num:338 - Reward:13.612538927646526
# Total timesteps:4932 - Episode num:339 - Reward:27.01374047800637
# Total timesteps:4939 - Episode num:340 - Reward:12.278280468466981
# Total timesteps:4958 - Episode num:341 - Reward:20.6644773144988
# Total timesteps:4976 - Episode num:342 - Reward:20.602453708217944
# Total timesteps:4986 - Episode num:343 - Reward:14.048171235671905
# Total timesteps:4994 - Episode num:344 - Reward:13.464720433032198
# Total timesteps:5005 - Episode num:345 - Reward:12.866036557464394
# Average award over 10 is: 37.600455850616896
# Total timesteps:5013 - Episode num:346 - Reward:12.750669519373332
# Total timesteps:5033 - Episode num:347 - Reward:20.53055380517762
# Total timesteps:5043 - Episode num:348 - Reward:16.105466356119724
# Total timesteps:5051 - Episode num:349 - Reward:14.5078686923036
# Total timesteps:5066 - Episode num:350 - Reward:16.340518259599047
# Total timesteps:5077 - Episode num:351 - Reward:17.030905601514682
# Total timesteps:5086 - Episode num:352 - Reward:12.46869626305561
# Total timesteps:5103 - Episode num:353 - Reward:19.20791178944928
# Total timesteps:5110 - Episode num:354 - Reward:13.512173809434172
# Total timesteps:5139 - Episode num:355 - Reward:26.975709551524783
# Total timesteps:5149 - Episode num:356 - Reward:13.10032377523603
# Total timesteps:5158 - Episode num:357 - Reward:13.543182352524308
# Total timesteps:5170 - Episode num:358 - Reward:14.914971216647245
# Total timesteps:5178 - Episode num:359 - Reward:12.573325210546317
# Total timesteps:5184 - Episode num:360 - Reward:10.173585653990447
# Total timesteps:5208 - Episode num:361 - Reward:21.77349302702641
# Total timesteps:5219 - Episode num:362 - Reward:15.73339005322341
# Total timesteps:5235 - Episode num:363 - Reward:21.601537296272
# Total timesteps:5250 - Episode num:364 - Reward:18.100753858234384
# Total timesteps:5259 - Episode num:365 - Reward:13.640098049085646
# Total timesteps:5266 - Episode num:366 - Reward:11.977136401779717
# Total timesteps:5280 - Episode num:367 - Reward:15.627157842433371
# Total timesteps:5289 - Episode num:368 - Reward:13.970775470526133
# Total timesteps:5304 - Episode num:369 - Reward:16.82693296793732
# Total timesteps:5318 - Episode num:370 - Reward:15.820111733744856
# Total timesteps:5348 - Episode num:371 - Reward:28.644433002015283
# Total timesteps:5363 - Episode num:372 - Reward:17.658553880616093
# Total timesteps:5374 - Episode num:373 - Reward:15.595154484281375
# Total timesteps:5387 - Episode num:374 - Reward:17.7052659474226
# Total timesteps:5405 - Episode num:375 - Reward:20.261063921361348
# Total timesteps:5423 - Episode num:376 - Reward:18.81957828690793
# Total timesteps:5434 - Episode num:377 - Reward:13.929482317346263
# Total timesteps:5442 - Episode num:378 - Reward:14.119004139507886
# Total timesteps:5470 - Episode num:379 - Reward:23.1643020235686
# Total timesteps:5488 - Episode num:380 - Reward:19.97739001158479
# Total timesteps:5501 - Episode num:381 - Reward:16.629573732767312
# Total timesteps:5511 - Episode num:382 - Reward:14.405287461788976
# Total timesteps:5519 - Episode num:383 - Reward:12.300303005774913
# Total timesteps:5537 - Episode num:384 - Reward:16.23072089551861
# Total timesteps:5553 - Episode num:385 - Reward:17.4615480765031
# Total timesteps:5574 - Episode num:386 - Reward:22.27113440691319
# Total timesteps:5581 - Episode num:387 - Reward:11.371107291876978
# Total timesteps:5591 - Episode num:388 - Reward:14.780805448294268
# Total timesteps:5606 - Episode num:389 - Reward:18.262374794439527
# Total timesteps:5617 - Episode num:390 - Reward:15.761918424117903
# Total timesteps:5626 - Episode num:391 - Reward:14.14015503316041
# Total timesteps:5640 - Episode num:392 - Reward:13.475891163243796
# Total timesteps:7830 - Episode num:536 - Reward:10.63602416187059
# Total timesteps:7848 - Episode num:537 - Reward:19.561033085871898
# Total timesteps:7859 - Episode num:538 - Reward:13.326256283573455
# Total timesteps:7867 - Episode num:539 - Reward:12.422929171327269
# Total timesteps:7881 - Episode num:540 - Reward:18.278213552779924
# Total timesteps:7903 - Episode num:541 - Reward:20.809830880677325
# Total timesteps:7914 - Episode num:542 - Reward:15.599678606519593
# Total timesteps:7921 - Episode num:543 - Reward:12.104517170252803
# Total timesteps:7940 - Episode num:544 - Reward:18.680536375482912
# Total timesteps:7951 - Episode num:545 - Reward:13.500397495734795
# Total timesteps:7976 - Episode num:546 - Reward:23.087952538298854
# Total timesteps:7993 - Episode num:547 - Reward:20.12661863617395
# Total timesteps:8013 - Episode num:548 - Reward:19.76352646665327
# Total timesteps:8027 - Episode num:549 - Reward:19.20587959335535
# Total timesteps:8046 - Episode num:550 - Reward:20.044375214489992
# Total timesteps:8065 - Episode num:551 - Reward:18.54679034069704
# Total timesteps:8073 - Episode num:552 - Reward:13.016690722016211
# Total timesteps:8082 - Episode num:553 - Reward:13.954400315946259
# Total timesteps:8088 - Episode num:554 - Reward:10.954644326138077
# Total timesteps:8103 - Episode num:555 - Reward:16.056366767849248
# Total timesteps:8116 - Episode num:556 - Reward:16.453509389903047
# Total timesteps:8124 - Episode num:557 - Reward:11.507627179886914
# Total timesteps:8134 - Episode num:558 - Reward:14.115717930403479
# Total timesteps:8142 - Episode num:559 - Reward:11.982640713124422
# Total timesteps:8176 - Episode num:560 - Reward:35.368289890461895
# Total timesteps:8185 - Episode num:561 - Reward:12.074917961815661
# Total timesteps:8195 - Episode num:562 - Reward:14.704051807973883
# Total timesteps:8206 - Episode num:563 - Reward:16.15978975095204
# Total timesteps:8216 - Episode num:564 - Reward:14.9829184575603
# Total timesteps:8225 - Episode num:565 - Reward:14.035017608237103
# Total timesteps:8244 - Episode num:566 - Reward:17.12834171416179
# Total timesteps:8258 - Episode num:567 - Reward:18.168256035393277
# Total timesteps:8269 - Episode num:568 - Reward:15.26159840418404
# Total timesteps:8278 - Episode num:569 - Reward:13.927947782575211
# Total timesteps:8298 - Episode num:570 - Reward:18.916318933505682
# Total timesteps:8314 - Episode num:571 - Reward:18.76938419803046
# Total timesteps:8327 - Episode num:572 - Reward:14.829180237898253
# Total timesteps:8350 - Episode num:573 - Reward:22.11251652778155
# Total timesteps:8367 - Episode num:574 - Reward:20.062346716749015
# Total timesteps:8377 - Episode num:575 - Reward:15.125634211450233
# Total timesteps:8387 - Episode num:576 - Reward:14.528504384653933
# Total timesteps:8396 - Episode num:577 - Reward:13.576890472794185
# Total timesteps:8409 - Episode num:578 - Reward:14.441892274514247
# Total timesteps:8427 - Episode num:579 - Reward:19.298717491942806
# Total timesteps:8450 - Episode num:580 - Reward:20.563602892836208
# Total timesteps:8459 - Episode num:581 - Reward:13.014037152803212
# Total timesteps:8472 - Episode num:582 - Reward:15.694166711404977
# Total timesteps:8491 - Episode num:583 - Reward:18.344819614636073
# Total timesteps:8512 - Episode num:584 - Reward:23.363218229374613
# Total timesteps:8533 - Episode num:585 - Reward:19.01046121817053
# Total timesteps:8549 - Episode num:586 - Reward:17.77892276773055
# Total timesteps:8558 - Episode num:587 - Reward:14.657265670424383
# Total timesteps:8579 - Episode num:588 - Reward:20.513628029063693
# Total timesteps:8589 - Episode num:589 - Reward:14.175590339874907
# Total timesteps:8613 - Episode num:590 - Reward:25.94436119957536
# Total timesteps:8622 - Episode num:591 - Reward:13.560458796139573
# Total timesteps:8631 - Episode num:592 - Reward:12.096258241227769
# Total timesteps:8644 - Episode num:593 - Reward:15.176727177714929
# Total timesteps:8653 - Episode num:594 - Reward:12.040595350679359
# Total timesteps:8662 - Episode num:595 - Reward:14.08278710195009
# Total timesteps:8675 - Episode num:596 - Reward:16.440166231608604
# Total timesteps:8688 - Episode num:597 - Reward:16.142782831142537
# Total timesteps:8709 - Episode num:598 - Reward:19.355936126926093
# Total timesteps:8717 - Episode num:599 - Reward:13.203623579761187
# Total timesteps:8735 - Episode num:600 - Reward:19.6797304147738
# Total timesteps:8742 - Episode num:601 - Reward:11.029058178368723
# Total timesteps:8753 - Episode num:602 - Reward:15.105700627843909
# Total timesteps:8761 - Episode num:603 - Reward:13.18375237500586
# Total timesteps:8777 - Episode num:604 - Reward:13.179949873502482
# Total timesteps:8799 - Episode num:605 - Reward:24.04931416333857
# Total timesteps:8814 - Episode num:606 - Reward:17.762046709144485
# Total timesteps:8824 - Episode num:607 - Reward:12.062625491606013
# Total timesteps:8846 - Episode num:608 - Reward:22.480256522393027
# Total timesteps:8856 - Episode num:609 - Reward:14.017796621375602
# Total timesteps:8875 - Episode num:610 - Reward:17.93942950927012
# Total timesteps:8884 - Episode num:611 - Reward:12.68433329086547
# Total timesteps:8903 - Episode num:612 - Reward:19.816714385435624
# Total timesteps:8911 - Episode num:613 - Reward:11.464290079117927
# Total timesteps:8933 - Episode num:614 - Reward:24.473088013831877
# Total timesteps:8953 - Episode num:615 - Reward:22.545941139454957
# Total timesteps:8965 - Episode num:616 - Reward:14.803697725337406
# Total timesteps:8973 - Episode num:617 - Reward:13.353691587231879
# Total timesteps:8994 - Episode num:618 - Reward:24.00568177411478
# Total timesteps:9007 - Episode num:619 - Reward:18.247667220426955
# Total timesteps:9030 - Episode num:620 - Reward:23.887903128849576
# Total timesteps:9042 - Episode num:621 - Reward:15.122824632280388
# Total timesteps:9058 - Episode num:622 - Reward:18.50828131426388
# Total timesteps:9079 - Episode num:623 - Reward:17.038906694542675
# Total timesteps:9110 - Episode num:624 - Reward:30.108064965976524
# Total timesteps:9125 - Episode num:625 - Reward:17.117143201931317
# Total timesteps:9137 - Episode num:626 - Reward:16.265364531427622
# Total timesteps:9151 - Episode num:627 - Reward:16.677874558429178
# Total timesteps:9168 - Episode num:628 - Reward:17.971859652444255
# Total timesteps:9176 - Episode num:629 - Reward:13.787902076357568
# Total timesteps:9194 - Episode num:630 - Reward:19.001078023297303
# Total timesteps:9879 - Episode num:678 - Reward:13.175376823471744
# Total timesteps:9886 - Episode num:679 - Reward:13.072080030252982
# Total timesteps:9895 - Episode num:680 - Reward:13.63475605603744
# Total timesteps:9910 - Episode num:681 - Reward:20.148153889398962
# Total timesteps:9925 - Episode num:682 - Reward:16.839606498873035
# Total timesteps:9934 - Episode num:683 - Reward:14.215999738409298
# Total timesteps:9943 - Episode num:684 - Reward:14.50740347977553
# Total timesteps:9953 - Episode num:685 - Reward:14.491877985357133
# Total timesteps:9964 - Episode num:686 - Reward:16.174020717834356
# Total timesteps:9990 - Episode num:687 - Reward:24.46510431171919
# Total timesteps:9998 - Episode num:688 - Reward:12.610215229648746
# Total timesteps:10059 - Episode num:689 - Reward:71.3661989990338
# Average award over 10 is: 79.11621837038523
# Total timesteps:10167 - Episode num:690 - Reward:108.0744431584248
# Total timesteps:10235 - Episode num:691 - Reward:74.8746095859249
# Total timesteps:10289 - Episode num:692 - Reward:60.83019944575788
# Total timesteps:10315 - Episode num:693 - Reward:24.088605583621337
# Total timesteps:10375 - Episode num:694 - Reward:64.58141164982804
# Total timesteps:10451 - Episode num:695 - Reward:88.019531152038
# Total timesteps:10517 - Episode num:696 - Reward:73.28557952242467
# Total timesteps:10565 - Episode num:697 - Reward:49.21287853847175
# Total timesteps:10694 - Episode num:698 - Reward:91.85155523547998
# Total timesteps:10756 - Episode num:699 - Reward:65.13131564986142
# Total timesteps:10811 - Episode num:700 - Reward:54.56154671593997
# Total timesteps:10850 - Episode num:701 - Reward:39.33159862378196
# Total timesteps:10943 - Episode num:702 - Reward:52.30229127473975
# Total timesteps:11018 - Episode num:703 - Reward:34.11574301969408
# Total timesteps:11064 - Episode num:704 - Reward:51.09683906469384
# Total timesteps:11140 - Episode num:705 - Reward:32.13682396503889
# Total timesteps:11182 - Episode num:706 - Reward:44.179060729924856
# Total timesteps:11238 - Episode num:707 - Reward:61.00467165849026
# Total timesteps:11313 - Episode num:708 - Reward:96.59836861599545
# Total timesteps:11409 - Episode num:709 - Reward:107.32212055188478
# Total timesteps:11490 - Episode num:710 - Reward:92.25992444715612
# Total timesteps:11552 - Episode num:711 - Reward:71.06689099434617
# Total timesteps:11632 - Episode num:712 - Reward:87.33283003829199
# Total timesteps:11697 - Episode num:713 - Reward:68.15924455353401
# Total timesteps:11766 - Episode num:714 - Reward:28.794967537631695
# Total timesteps:11826 - Episode num:715 - Reward:27.883194553244305
# Total timesteps:11904 - Episode num:716 - Reward:87.48397091500074
# Total timesteps:11984 - Episode num:717 - Reward:102.20063462432309
# Total timesteps:12076 - Episode num:718 - Reward:49.811146075823494
# Total timesteps:12174 - Episode num:719 - Reward:108.66587186200377
# Total timesteps:12264 - Episode num:720 - Reward:28.359251236072545
# Total timesteps:12317 - Episode num:721 - Reward:77.28413261859959
# ...
# Total timesteps:149390 - Episode num:1571 - Reward:85.19908990093265
# Total timesteps:150390 - Episode num:1572 - Reward:896.7920530887912
# Average award over 10 is: 706.806151809125
# Total timesteps:151390 - Episode num:1573 - Reward:834.4578723592003
# Total timesteps:152390 - Episode num:1574 - Reward:851.5002205176737
# Total timesteps:152976 - Episode num:1575 - Reward:557.2789975037153
# Total timesteps:153732 - Episode num:1576 - Reward:714.4250071840353
# Total timesteps:154007 - Episode num:1577 - Reward:287.77611386543214
# Total timesteps:154784 - Episode num:1578 - Reward:698.1674964127512
# Total timesteps:155316 - Episode num:1579 - Reward:482.3159982547304
# Average award over 10 is: 471.48193762628864
# Total timesteps:156316 - Episode num:1580 - Reward:773.3479789708575
# Total timesteps:157316 - Episode num:1581 - Reward:659.0348390178347
# Total timesteps:158316 - Episode num:1582 - Reward:508.0370653690471
# Total timesteps:159316 - Episode num:1583 - Reward:750.0899014777557
# Total timesteps:160316 - Episode num:1584 - Reward:633.0203478336039
# Average award over 10 is: 169.27540802345115
# Total timesteps:160436 - Episode num:1585 - Reward:-0.48015432690499305
# Total timesteps:160490 - Episode num:1586 - Reward:9.446074222545004
# Total timesteps:160581 - Episode num:1587 - Reward:110.69327600251981
# Total timesteps:160649 - Episode num:1588 - Reward:11.696584917163584
# Total timesteps:160715 - Episode num:1589 - Reward:14.66936820843527
# Total timesteps:160771 - Episode num:1590 - Reward:4.265041437929136
# Total timesteps:161771 - Episode num:1591 - Reward:781.4962549707968
# Total timesteps:161838 - Episode num:1592 - Reward:10.183096502058728
# Total timesteps:161893 - Episode num:1593 - Reward:24.101240402004542
# Total timesteps:161949 - Episode num:1594 - Reward:7.6191042882499875
# Total timesteps:162008 - Episode num:1595 - Reward:9.784128755089196
# Total timesteps:162075 - Episode num:1596 - Reward:13.454422193855628
# Total timesteps:163075 - Episode num:1597 - Reward:617.3418641716057
# Total timesteps:163116 - Episode num:1598 - Reward:38.84897324513113
# Total timesteps:163173 - Episode num:1599 - Reward:58.80809999124528
# Total timesteps:163261 - Episode num:1600 - Reward:37.65172805041647
# Total timesteps:164261 - Episode num:1601 - Reward:694.8269074850939
# Total timesteps:164303 - Episode num:1602 - Reward:41.262638485179565
# Total timesteps:164343 - Episode num:1603 - Reward:38.87841379776388
# Total timesteps:164670 - Episode num:1604 - Reward:287.8906497958022
# Total timesteps:164797 - Episode num:1605 - Reward:119.30068515432187
# Total timesteps:164898 - Episode num:1606 - Reward:104.95568181636997
# Total timesteps:164987 - Episode num:1607 - Reward:100.95424283958253
# Total timesteps:165191 - Episode num:1608 - Reward:209.04586834561462
# Average award over 10 is: 159.51391115974485
# Total timesteps:165397 - Episode num:1609 - Reward:194.07232396850145
# Total timesteps:165600 - Episode num:1610 - Reward:9.904729648784196
# Total timesteps:165722 - Episode num:1611 - Reward:115.01201577208128
# Total timesteps:166024 - Episode num:1612 - Reward:162.04824486172961
# Total timesteps:167024 - Episode num:1613 - Reward:428.60679529502266
# Total timesteps:168024 - Episode num:1614 - Reward:332.16072390941025
# Total timesteps:168161 - Episode num:1615 - Reward:133.5161415990509
# Total timesteps:168237 - Episode num:1616 - Reward:22.994688579601625
# Total timesteps:168366 - Episode num:1617 - Reward:-46.88483944730758
# Total timesteps:168509 - Episode num:1618 - Reward:145.19559345068112
# Total timesteps:168578 - Episode num:1619 - Reward:18.12790056094176
# Total timesteps:168763 - Episode num:1620 - Reward:170.53073925915484
# Total timesteps:169088 - Episode num:1621 - Reward:311.36589173571264
# Total timesteps:170088 - Episode num:1622 - Reward:567.9940263233202
# Average award over 10 is: 461.95349941493697
# Total timesteps:171088 - Episode num:1623 - Reward:1008.5127219952891
# Total timesteps:171177 - Episode num:1624 - Reward:87.12144624124983
# Total timesteps:171260 - Episode num:1625 - Reward:13.59426605497429
# Total timesteps:171337 - Episode num:1626 - Reward:94.16531503824189
# Total timesteps:171420 - Episode num:1627 - Reward:84.17114706260176
# Total timesteps:171531 - Episode num:1628 - Reward:23.208729563961324
# Total timesteps:171603 - Episode num:1629 - Reward:67.92778129656655
# Total timesteps:171694 - Episode num:1630 - Reward:107.05420755153929
# Total timesteps:171772 - Episode num:1631 - Reward:4.0010597589757
# Total timesteps:171947 - Episode num:1632 - Reward:208.56770542128743
# Total timesteps:172003 - Episode num:1633 - Reward:72.32458251569449
# Total timesteps:172061 - Episode num:1634 - Reward:25.272264316231517
# Total timesteps:172130 - Episode num:1635 - Reward:-2.1590810012850676
# Total timesteps:172219 - Episode num:1636 - Reward:26.59115793298917
# Total timesteps:173219 - Episode num:1637 - Reward:693.7980995639828
# Total timesteps:173312 - Episode num:1638 - Reward:89.94859651732885
# Total timesteps:174312 - Episode num:1639 - Reward:367.3416803274743
# Total timesteps:175312 - Episode num:1640 - Reward:533.2767087765359
# Average award over 10 is: 220.43387041389002
# Total timesteps:176312 - Episode num:1641 - Reward:645.1365213168477
# Total timesteps:176409 - Episode num:1642 - Reward:114.77946707179872
# Total timesteps:176492 - Episode num:1643 - Reward:38.448959334092805
# Total timesteps:176610 - Episode num:1644 - Reward:17.344688304874243
# Total timesteps:176719 - Episode num:1645 - Reward:6.519737389943343
# Total timesteps:176817 - Episode num:1646 - Reward:11.951558556394744
# Total timesteps:177817 - Episode num:1647 - Reward:675.2634789277341
# Total timesteps:178817 - Episode num:1648 - Reward:545.428425485495
# Total timesteps:179817 - Episode num:1649 - Reward:469.9871865688564
# Total timesteps:180817 - Episode num:1650 - Reward:582.9924856475158
# Average award over 10 is: 791.7978427666719
# Total timesteps:181817 - Episode num:1651 - Reward:731.8409570593739
# Total timesteps:182817 - Episode num:1652 - Reward:720.8997200935077
# Total timesteps:183817 - Episode num:1653 - Reward:911.6421625111813
# Total timesteps:184817 - Episode num:1654 - Reward:1011.4751121886258
# Total timesteps:185735 - Episode num:1655 - Reward:981.8962518178089
# Average award over 10 is: 800.80891726822
# Total timesteps:186735 - Episode num:1656 - Reward:995.7786889003188
# Total timesteps:187735 - Episode num:1657 - Reward:1171.8167346390485
# Total timesteps:187860 - Episode num:1658 - Reward:113.1820142312645
# Total timesteps:188860 - Episode num:1659 - Reward:726.1444368106291
# Total timesteps:189004 - Episode num:1660 - Reward:122.31945004732744
# Total timesteps:189969 - Episode num:1661 - Reward:778.6282427380022
# Total timesteps:190969 - Episode num:1662 - Reward:656.2949513721799
# Average award over 10 is: 49.05270897574287
# Total timesteps:191013 - Episode num:1663 - Reward:43.878767441072085
# Total timesteps:191268 - Episode num:1664 - Reward:254.46536567344984
# Total timesteps:191406 - Episode num:1665 - Reward:108.42240346081863
# Total timesteps:191993 - Episode num:1666 - Reward:515.1582891471006
# Total timesteps:192155 - Episode num:1667 - Reward:175.42704703404314
# Total timesteps:193155 - Episode num:1668 - Reward:965.8984185658162
# Total timesteps:194155 - Episode num:1669 - Reward:604.3549635478547
# Total timesteps:194696 - Episode num:1670 - Reward:418.78208903675056
# Total timesteps:195107 - Episode num:1671 - Reward:424.9486167437917
# Average award over 10 is: 569.3749903774026
# Total timesteps:195507 - Episode num:1672 - Reward:396.8516716208586
# Total timesteps:196364 - Episode num:1673 - Reward:883.7772688445382
# Total timesteps:197364 - Episode num:1674 - Reward:1161.0782185671271
# Total timesteps:198364 - Episode num:1675 - Reward:867.2579509389105
# Total timesteps:199364 - Episode num:1676 - Reward:1042.6540631544844
# Total timesteps:200314 - Episode num:1677 - Reward:953.5818187312343
# Average award over 10 is: 790.2283261367131
# Total timesteps:200725 - Episode num:1678 - Reward:456.5839276357574
# Total timesteps:200902 - Episode num:1679 - Reward:200.49415458184558
# Total timesteps:201902 - Episode num:1680 - Reward:1182.2238690874922
# Total timesteps:202272 - Episode num:1681 - Reward:469.03905327014473
# Total timesteps:202980 - Episode num:1682 - Reward:577.6849766900226
# Total timesteps:203980 - Episode num:1683 - Reward:997.0024601376982
# Total timesteps:204662 - Episode num:1684 - Reward:758.3621643766168
# Total timesteps:205434 - Episode num:1685 - Reward:915.984447298853
# Average award over 10 is: 1060.1702694390665
# Total timesteps:206107 - Episode num:1686 - Reward:678.8573688286937
# Total timesteps:206785 - Episode num:1687 - Reward:692.5738826653353
# Total timesteps:207785 - Episode num:1688 - Reward:1112.3680999528501
# Total timesteps:208056 - Episode num:1689 - Reward:297.7733218858279
# Total timesteps:208275 - Episode num:1690 - Reward:241.02106659557512
# Total timesteps:208626 - Episode num:1691 - Reward:409.16228074943626
# Total timesteps:209626 - Episode num:1692 - Reward:1284.7890790198503
# Total timesteps:210626 - Episode num:1693 - Reward:1137.3643831821007
# Average award over 10 is: 288.52960692171257
# Total timesteps:210710 - Episode num:1694 - Reward:88.45196907878257
# Total timesteps:211710 - Episode num:1695 - Reward:1187.9148367704736
# Total timesteps:211765 - Episode num:1696 - Reward:66.22935861126666
# Total timesteps:211938 - Episode num:1697 - Reward:207.38640227881868
# Total timesteps:212025 - Episode num:1698 - Reward:97.55621216800049
# Total timesteps:212086 - Episode num:1699 - Reward:70.57088839620391
# Total timesteps:212150 - Episode num:1700 - Reward:76.0104383184253
# Total timesteps:212192 - Episode num:1701 - Reward:54.312135711836525
# Total timesteps:212234 - Episode num:1702 - Reward:52.249001985674205
# Total timesteps:212281 - Episode num:1703 - Reward:55.743298063047355
# Total timesteps:212337 - Episode num:1704 - Reward:68.68668733839561
# Total timesteps:212387 - Episode num:1705 - Reward:62.14826455273729
# Total timesteps:212424 - Episode num:1706 - Reward:43.605909479097555
# Total timesteps:212462 - Episode num:1707 - Reward:45.24127011674122
# Total timesteps:212500 - Episode num:1708 - Reward:46.605998407882396
# Total timesteps:212557 - Episode num:1709 - Reward:68.87573564875112
# Total timesteps:212602 - Episode num:1710 - Reward:56.88745778204745
# Total timesteps:212668 - Episode num:1711 - Reward:73.98267019562091
# Total timesteps:212848 - Episode num:1712 - Reward:209.18969316841782
# Total timesteps:213094 - Episode num:1713 - Reward:276.5027299809645
# Total timesteps:213148 - Episode num:1714 - Reward:63.75863740025791
# Total timesteps:213319 - Episode num:1715 - Reward:207.42370319692404
# Total timesteps:213522 - Episode num:1716 - Reward:243.80747964892382
# Total timesteps:213573 - Episode num:1717 - Reward:60.31523284893033
# Total timesteps:213625 - Episode num:1718 - Reward:59.584834707808156
# Total timesteps:213691 - Episode num:1719 - Reward:80.39558525873117
# Total timesteps:214478 - Episode num:1720 - Reward:969.8385720520024
# Total timesteps:215134 - Episode num:1721 - Reward:815.0123710801699
# Average award over 10 is: 785.2381554968537
# Total timesteps:216134 - Episode num:1722 - Reward:980.1539240792151
# Total timesteps:217134 - Episode num:1723 - Reward:1211.0823944670894
# Total timesteps:218134 - Episode num:1724 - Reward:951.1413899229962
# Total timesteps:218614 - Episode num:1725 - Reward:540.7759487375766
# Total timesteps:219614 - Episode num:1726 - Reward:1125.6024988527067
# Total timesteps:220516 - Episode num:1727 - Reward:949.693193093293
# Average award over 10 is: 505.55246703045896
# Total timesteps:221018 - Episode num:1728 - Reward:497.64690515219183
# Total timesteps:222018 - Episode num:1729 - Reward:908.3890270741379
# Total timesteps:222559 - Episode num:1730 - Reward:580.5557805006838
# Total timesteps:223491 - Episode num:1731 - Reward:1048.71330296612
# Total timesteps:224319 - Episode num:1732 - Reward:914.6992200479285
# Total timesteps:225319 - Episode num:1733 - Reward:1246.2114719600088
# Average award over 10 is: 826.0735497134723
# Total timesteps:226319 - Episode num:1734 - Reward:866.6158608580758
# Total timesteps:227319 - Episode num:1735 - Reward:995.453142704837
# Total timesteps:228319 - Episode num:1736 - Reward:1112.7964660518599
# Total timesteps:228523 - Episode num:1737 - Reward:211.35101261888937
# Total timesteps:229523 - Episode num:1738 - Reward:1039.7380310989001
# Total timesteps:230523 - Episode num:1739 - Reward:1058.1675893495767
# Average award over 10 is: 840.9410629500289
# Total timesteps:231523 - Episode num:1740 - Reward:823.85077889803
# Total timesteps:231600 - Episode num:1741 - Reward:84.44714237944845
# Total timesteps:231760 - Episode num:1742 - Reward:157.22038172906682
# Total timesteps:231907 - Episode num:1743 - Reward:140.96132106566517
# Total timesteps:231976 - Episode num:1744 - Reward:71.0846572108078
# Total timesteps:232918 - Episode num:1745 - Reward:1018.7333142827756
# Total timesteps:232990 - Episode num:1746 - Reward:74.9476629046416
# Total timesteps:233990 - Episode num:1747 - Reward:970.3394642847119
# Total timesteps:234990 - Episode num:1748 - Reward:983.6645853778842
# Total timesteps:235475 - Episode num:1749 - Reward:479.6394105719872
# Average award over 10 is: 324.43469301290713
# Total timesteps:235609 - Episode num:1750 - Reward:156.44436792276255
# Total timesteps:235778 - Episode num:1751 - Reward:175.63441875351802
# Total timesteps:236604 - Episode num:1752 - Reward:808.0008872460097
# Total timesteps:236836 - Episode num:1753 - Reward:270.6295000596313
# Total timesteps:237524 - Episode num:1754 - Reward:639.0623674025732
# Total timesteps:237623 - Episode num:1755 - Reward:122.86620566037203
# Total timesteps:238623 - Episode num:1756 - Reward:994.0838810893408
# Total timesteps:238762 - Episode num:1757 - Reward:160.8332293428976
# Total timesteps:239762 - Episode num:1758 - Reward:682.8394061969619
# Total timesteps:240762 - Episode num:1759 - Reward:807.3537573193292
# Average award over 10 is: 759.8878118385608
# Total timesteps:241762 - Episode num:1760 - Reward:801.18260880803
# Total timesteps:242331 - Episode num:1761 - Reward:523.668979396528
# Total timesteps:243331 - Episode num:1762 - Reward:766.151243302525
# Total timesteps:244331 - Episode num:1763 - Reward:901.7233495687361
# Total timesteps:244427 - Episode num:1764 - Reward:108.04971670265064
# Total timesteps:245427 - Episode num:1765 - Reward:1046.4790664842744
# Average award over 10 is: 1038.1488869327318
# Total timesteps:246427 - Episode num:1766 - Reward:1192.750911766081
# Total timesteps:247384 - Episode num:1767 - Reward:1078.8411066895956
# Total timesteps:248384 - Episode num:1768 - Reward:830.4003678152258
# Total timesteps:249209 - Episode num:1769 - Reward:934.4197173041985
# Total timesteps:250209 - Episode num:1770 - Reward:1159.8210127107986
# Average award over 10 is: 1037.5323618826937
# Total timesteps:251209 - Episode num:1771 - Reward:1043.0057990651264
# Total timesteps:252209 - Episode num:1772 - Reward:1028.528786907301
# Total timesteps:253209 - Episode num:1773 - Reward:925.1018418745679
# Total timesteps:254209 - Episode num:1774 - Reward:1055.272596165084
# Total timesteps:255209 - Episode num:1775 - Reward:1018.9493834792402
# Average award over 10 is: 1121.5075506677695
# Total timesteps:256209 - Episode num:1776 - Reward:1109.1422577265455
# Total timesteps:256323 - Episode num:1777 - Reward:131.73325354740177
# Total timesteps:257209 - Episode num:1778 - Reward:895.4293574160789
# Total timesteps:258209 - Episode num:1779 - Reward:1109.0898033572935
# Total timesteps:259209 - Episode num:1780 - Reward:899.9589627295189
# Total timesteps:260209 - Episode num:1781 - Reward:912.1575272980846
# Average award over 10 is: 940.8349161986787
# Total timesteps:261209 - Episode num:1782 - Reward:942.919624601113
# Total timesteps:262209 - Episode num:1783 - Reward:938.8566386955101
# Total timesteps:263209 - Episode num:1784 - Reward:995.7776831717355
# Total timesteps:264209 - Episode num:1785 - Reward:956.2523362642362
# Total timesteps:265209 - Episode num:1786 - Reward:907.2748156117236

# %%
#test

# %%
pip install pybullet
# Out:
# Requirement already satisfied: pybullet in /usr/local/lib/python3.7/dist-packages (3.2.1)

# %%
import os
import time
import random

import numpy as np
import matplotlib.pyplot as plt

import gym
import pybullet_envs

import torch
import torch.nn as nn
import torch.nn.functional as F

from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %%
class ReplayBuffer(object):
    def __init__(self, max_size=1e6):
        self.storage = []
        self.max_size = max_size
        self.ptr = 0
    
    def add(self, transition):
        if len(self.storage) == self.max_size:
            self.storage[int(self.ptr)] = transition
            self.ptr = (self.ptr+1) % self.max_size
        else:
            self.storage.append(transition) 
    
    def sample(self, batch_size):
        sample_data = np.random.randint(0, len(self.storage), size=batch_size)

        states_ = []
        next_states_ = [] 
        actions_ = []
        rewards_ = []
        dones_= []
        for i in sample_data:
            state, next_state, action, reward, done = self.storage[i]
            states_.append(state)
            next_states_.append(next_state)
            actions_.append(action)
            rewards_.append(reward)
            dones_.append(done)
        
        return np.array(states_), np.array(next_states_), np.array(actions_), np.array(rewards_).reshape(-1,1), np.array(dones_).reshape(-1,1)

class Actor(nn.Module):
    def __init__(self, input, action, cut):#action is the number outputs | output is the number of actions
        super(Actor,self).__init__()
        self.fully01 = nn.Linear(input, 400)
        self.fully02 = nn.Linear(400,300)
        self.last = nn.Linear(300, action)
        self.cut = cut

    def forward(self, x):
        x = F.relu(self.fully01(x))
        x = F.relu(self.fully02(x))
        return self.cut * torch.tanh(self.last(x))#the cut to adjust to the output levels. higher or lower that -1,1                             

#since we need two pair of critics, im making both on the same class.
#the name of the class should be DoubleCritic,PairCritic..etc
class Critic(nn.Module):
    def __init__(self, input, action):
        super(Critic, self).__init__()
        #first
        self.fully01 = nn.Linear(input+action, 400)
        self.fully02 = nn.Linear(400,300)
        self.fully03 = nn.Linear(300, 1)

        #second
        self.fully11 = nn.Linear(input+action, 400)
        self.fully22 = nn.Linear(400,300)
        self.fully33 = nn.Linear(300, 1)

    def forward(self, x, u):
        xu = torch.cat([x,u], 1)
        #first
        x = F.relu(self.fully01(xu))
        x = F.relu(self.fully02(x))
        x = self.fully03(x)
        #Second
        y = F.relu(self.fully11(xu))
        y = F.relu(self.fully22(y))
        y = self.fully33(y)
        return x, y

    def Q1(self, x, u):
        xu = torch.cat([x,u], 1)
        x = F.relu(self.fully01(xu))
        x = F.relu(self.fully02(x))
        x = self.fully03(x)
        return x

#training
class TD3(object):
    def __init__(self, state_dim, action_dim, max_action):
        # actors
        self.Actor = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target.load_state_dict(self.Actor.state_dict())

        # actor optimizer
        self.Actor_optimizer = torch.optim.Adam(self.Actor.parameters())

        ## Critic 
        self.Critic = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_Target = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_Target.load_state_dict(self.Critic.state_dict())

        ## Critic optimizer
        self.Critic_optimizer = torch.optim.Adam(self.Critic.parameters())

        ### Max_Action is the cut/clip
        self.max_action =  max_action

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1,-1)).to(DEVICE)
        return self.Actor(state).cpu().data.numpy().flatten()
        #return self.Actor(state).data.numpy().flatten()

    def save(self, filename, directory):
        torch.save(self.Actor.state_dict(),'%s/%s_Actor.pth' % (directory,filename))
        torch.save(self.Critic.state_dict(),'%s/%s_Critic.pth' % (directory,filename))

    def load(self, filename, directory):
        self.Actor.load_state_dict(torch.load('%s/%s_Actor.pth' % (directory,filename)))
        self.Critic.load_state_dict(torch.load('%s/%s_Critic.pth' % (directory,filename)))
    
    def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
        for i in range(iterations):
            states_, next_states_, actions_, rewards_, dones_ = replay_buffer.sample(batch_size)

            state = torch.Tensor(states_).to(DEVICE)
            next_state = torch.Tensor(next_states_).to(DEVICE)
            action = torch.Tensor(actions_).to(DEVICE)
            reward = torch.Tensor(rewards_).to(DEVICE)
            done = torch.Tensor(dones_).to(DEVICE)

            next_action = self.Actor_Target(next_state)

            noise = torch.Tensor(actions_).data.normal_(0, policy_noise).to(DEVICE)
            noise = noise.clamp(-noise_clip,noise_clip)
            next_action = (next_action+noise).clamp(-self.max_action, self.max_action)

            Target_Q1, Target_Q2 = self.Critic_Target(next_state, next_action)
            
            #when episode is over 1, not over 0. 
            # we detached because adding the reward which is the output 
            #of nn to the computaional graph would not be what we want.
            Target_Q = torch.min(Target_Q1, Target_Q2)
            Target_Q = reward + (discount * Target_Q * (1 - done)).detach()
          
            Current_Q1, Current_Q2 = self.Critic(state, action)
            critic_loss = F.mse_loss(Current_Q1,Target_Q) + F.mse_loss(Current_Q2, Target_Q)

            self.Critic_optimizer.zero_grad()
            critic_loss.backward()
            self.Critic_optimizer.step()

            if not i % policy_freq:
                actor_loss = -self.Critic.Q1(state, self.Actor(state)).mean()
                self.Actor_optimizer.zero_grad()
                actor_loss.backward()
                self.Actor_optimizer.step()

                for param, target_param in zip(self.Actor.parameters(), self.Actor_Target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)
                
                
                for param, target_param in zip(self.Critic.parameters(), self.Critic_Target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)
                
def evaluate_policy(policy, episodes=10):
    avg_awards = 0
    for _ in range(episodes):
        obs = env.reset()
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done, _ = env.step(action)
            avg_awards += reward
    avg_awards /= episodes
    print(f"Average award over {episodes} is:",avg_awards)
    return avg_awards

def mkdir(base, name):
    path = os.path.join(base,name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
env_name = 'Walker2DBulletEnv-v0'
seed = 0
file_name = f"TD3--{env_name}--seed({seed})"
print(file_name)

eval_episodes = 10
save_env_vid = True
env = gym.make(env_name)

max_episode_step = env._max_episode_steps
if save_env_vid:
    env = wrappers.Monitor(env, monitor_dir, force=True)
    env.reset()
#setting env
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
#agent
policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, "./pytorch_models/")
_ = evaluate_policy(policy, episodes=eval_episodes)
# Out:
# TD3--Walker2DBulletEnv-v0--seed(0)
# Average award over 10 is: 74.56413918364066
