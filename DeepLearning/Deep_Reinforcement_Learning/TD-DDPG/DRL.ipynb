# %% [markdown]
# ### **Installing PreRequisites**

# %%
pip install pybullet
# Out:
# Requirement already satisfied: pybullet in /usr/local/lib/python3.7/dist-packages (3.2.1)

# %% [markdown]
# ### **Libraries**

# %%
import os
import time
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gym
import pybullet_envs

import torch
import torch.nn as nn
import torch.nn.functional as F

from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# ### **GPU - Check for GPU**

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('GPU on:', True if torch.cuda.is_available() else False, '| Device:',DEVICE)
# Out:
# GPU on: True | Device: cuda

# %% [markdown]
# ### **Connection to Google Drive - Google Drive Mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Memory class - Memory definition**

# %%
class Memory_(object):
    def __init__(self, max_size=1e6):
        self.memory = []
        self.max_size = max_size
        self.loc = 0

    def add(self, transition):
        if len(self.memory) == self.max_size:
            self.memory[int(self.loc)] == transition
            self.loc = (self.loc+1) % self.max_size
        else:
            self.memory.append(transition)
        
    def sample(self, batch_size):
        states_ = []
        next_states_ = [] 
        actions_ = []
        rewards_ = []
        dones_= []

        sample_data = np.random.randint(0 , len(self.memory), size=batch_size)
        for i in sample_data:
            state, next_state, action, reward, done = self.memory[i]
            states_.append(state)
            next_states_.append(next_state)
            actions_.append(action)
            rewards_.append(reward)
            dones_.append(done)

        return np.array(states_), np.array(next_states_), np.array(actions_), np.array(rewards_).reshape(-1,1), np.array(dones_).reshape(-1,1)

# %% [markdown]
# ### **Actor Model - model definition**

# %%
#two models: 
#one for Actor_model
#second for Actor_target
class Actor(nn.Module):
    def __init__(self, input, action, limit):
        """
        action is the number outputs 
        output is the number of actions
        limit is the max action set by the environment:
        limit is used to adjust to the output levels. higher or lower than -1,1 
        """
        super(Actor,self).__init__()
        self.fully01 = nn.Linear(input, 400)
        self.fully02 = nn.Linear(400,300)
        self.last = nn.Linear(300, action)
        self.limit = limit

    def forward(self, x):
        x = F.relu(self.fully01(x))
        x = F.relu(self.fully02(x))
        x = self.limit * torch.tanh(self.last(x))    
        return x

# %% [markdown]
# ### **Critic Model - model definition**

# %%
#since we need two pair of critics, im making one class for both pair.
#this model will be used 4 times. Twice for the Critic_Model and twice
#for the Critic_Target adding up to 4 models total.
class Critic(nn.Module):
    def __init__(self, input, action):
        super(Critic, self).__init__()
        self.fully01 = nn.Linear(input+action, 400)
        self.fully02 = nn.Linear(400,300)
        self.fully03 = nn.Linear(300, 1)

    def forward(self, x, u):
        x = torch.cat([x,u], 1)
        x = F.relu(self.fully01(x))
        x = F.relu(self.fully02(x))
        x = self.fully03(x)
        return x

# %% [markdown]
# ### **Deep Reinforcemenet Learning Model - model definition**
# #### **& Model Training Function**

# %%
#training
class MODEL_DRL(object):
    def __init__(self, state_dim, action_dim, max_action):
        # actors
        self.Actor = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target = Actor(state_dim, action_dim, max_action).to(DEVICE)
        self.Actor_Target.load_state_dict(self.Actor.state_dict())

        # actor optimizer
        self.Actor_optimizer = torch.optim.Adam(self.Actor.parameters())

        ## Critics
        ###Critic MODEL
        self.Critic_left = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_right = Critic(state_dim, action_dim).to(DEVICE)
        ###Critic TARGET
        self.Critic_Target_left = Critic(state_dim, action_dim).to(DEVICE)
        self.Critic_Target_right = Critic(state_dim, action_dim).to(DEVICE)

        ###init weights 
        self.Critic_Target_left.load_state_dict(self.Critic_left.state_dict())
        self.Critic_Target_right.load_state_dict(self.Critic_left.state_dict())

        ## Critic optimizer
        self.Critic_optimizer_left = torch.optim.Adam(self.Critic_left.parameters())
        self.Critic_optimizer_right = torch.optim.Adam(self.Critic_right.parameters())

        ### Max_Action is the cut/clip
        self.max_action =  max_action

    def get_action(self, state):
        state = torch.FloatTensor(state.reshape(1,-1)).to(DEVICE)
        return self.Actor(state).cpu().data.numpy().flatten()

    def save(self, fname, directory):
        torch.save(self.Actor.state_dict(),f'{directory}/{fname}_Actor.pth')
        torch.save(self.Critic_left.state_dict(),f'{directory}/{fname}_Critic_left.pth')
        torch.save(self.Critic_right.state_dict(), f'{directory}/{fname}_Critic_right.pth')

    def load(self, fname, directory):
        self.Actor.load_state_dict(torch.load(f'{directory}/{fname}_Actor.pth'))
        self.Critic_left.load_state_dict(torch.load(f'{directory}/{fname}_Critic_left.pth'))
        self.Critic_right.load_state_dict(torch.load(f'{directory}/{fname}_Critic_right.pth'))
    
    def train(self, Memory, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
        for i in range(iterations):
            # get samples from the memory
            states_, next_states_, actions_, rewards_, dones_ = Memory.sample(batch_size)
            # converting the sample to torch-tenspr
            # moving the tensor to device:gpu/cpu
            state = torch.Tensor(states_).to(DEVICE)
            next_state = torch.Tensor(next_states_).to(DEVICE)
            action = torch.Tensor(actions_).to(DEVICE)
            reward = torch.Tensor(rewards_).to(DEVICE)
            done = torch.Tensor(dones_).to(DEVICE)
            #passing in the next-state to get the action for the next state.
            next_action = self.Actor_Target(next_state)
            #we add noise(bias) to the next-action
            #we limit/clip the noise to limit we want 0.5
            #we limit/clip the next-action to the environment limits
            noise = torch.Tensor(actions_).data.normal_(0, policy_noise).to(DEVICE)
            noise = noise.clamp(-noise_clip,noise_clip)
            next_action = (next_action+noise).clamp(-self.max_action, self.max_action)
            #we get the Q vlues for the Target Critice models
            Target_Q1 = self.Critic_Target_left(next_state, next_action)
            Target_Q2 = self.Critic_Target_right(next_state, next_action)
            #we select the minimum to not be optimistic
            Target_Q = torch.min(Target_Q1, Target_Q2)
            #we calculate the Q value= (r + y * Q)
            #the (1-done) for when the episode is over its 1,
            # when its not over its 0. 
            #we detached because adding the reward which is the output 
            #of nn to the computaional graph would not be what we want.
            Target_Q = reward + (discount * Target_Q * (1 - done)).detach()
            #we get the Q values for the critic models
            Current_Q1 = self.Critic_left(state, action)
            Current_Q2 = self.Critic_right(state, action)
            #we use the critic_model_Q values with the critic Q values calculated
            #above to get the loss
            critic_loss = F.mse_loss(Current_Q1,Target_Q) + F.mse_loss(Current_Q2, Target_Q)
            #setting the optim to zero
            self.Critic_optimizer_left.zero_grad()
            self.Critic_optimizer_right.zero_grad()
            #getting the backward
            critic_loss.backward()
            #doing the stop
            self.Critic_optimizer_left.step()
            self.Critic_optimizer_right.step()
            #if i % polic_freq(how often we update the models) == 0: do the below
            if not i % policy_freq:
                #getting the negative to apply gradient ascent on actor model
                #based on the left/first critic model Q output
                action_for_update = self.Actor(state)
                actor_loss = -self.Critic_left(state, action_for_update).mean()
                self.Actor_optimizer.zero_grad()
                actor_loss.backward()
                self.Actor_optimizer.step()
                #we are slowly updating the target model after 
                #X number of iterations
                #by slowly I mean using polyak update. 
                #everytime a percentage of the model is affecting the target model
                for param, target_param in zip(self.Actor.parameters(), self.Actor_Target.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)
                
                for param, target_param in zip(self.Critic_left.parameters(), self.Critic_Target_left.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)

                for param, target_param in zip(self.Critic_right.parameters(), self.Critic_Target_right.parameters()):
                    target_param.data.copy_(tau*param.data +(1-tau)*target_param.data)

# %% [markdown]
# ### **Evaluation of the model**
# Average-rewards over number of episodes

# %%
def evaluate(policy, episodes=10):
    total_rewards = 0
    for _ in range(episodes):
        tmp_done = False
        tmp_state = env.reset()
        while not tmp_done:
            tmp_state, tmp_reward, tmp_done, _ = env.step(policy.get_action(np.array(tmp_state)))
            total_rewards += tmp_reward
    total_rewards /= episodes
    print(f"Average award over {episodes} is:", total_rewards)
    return total_rewards

# %% [markdown]
# ### **Hyper-Parameters and Parameters**

# %%
#hyper-parameters
save_model = True
seed = 0

start_timesteps = 1e4
#max_timesteps= 6e5
max_timesteps= 15e3

batch_size = 100
policy_freq = 2
eval_freq = 5e3

discount = 0.99

expi_noise = 0.1
policy_noise = 0.2
noise_clip = 0.5
tau = 0.005

file_name = f"MODEL_DRL--{env_name}--seed({seed})"
env_name = 'HopperBulletEnv-v0'

# %% [markdown]
# ### **Environment initialization**

# %%
env = gym.make(env_name)
print("ENV:",env_name)
# Out:
# ENV: HopperBulletEnv-v0

# %% [markdown]
# ### **Environment Setting**
# Setting all randoms to a fixed seed of 0

# %%
#setting env
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ### **Model and Memory initialization**
# Model: Is a Deep Reinforcement Learning<br>
# Memory: Is where the model will pick samples to train from/on.

# %%
policy = MODEL_DRL(state_dim, action_dim, max_action)
Memory = Memory_()

# %% [markdown]
# ### **Setting basemodel**
# evaluation of the model before training

# %%
evaluation = [evaluate(policy)]
# Out:
# Average award over 10 is: 30.413425844018196

# %%
#initializing the variables
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True

# %% [markdown]
# ### **Training**

# %%
while total_timesteps < max_timesteps:
    if done:
        if total_timesteps != 0:
            print(f'Total timesteps:{total_timesteps} - Episode:{episode_num} - Reward:{episode_reward}')
            policy.train(Memory, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)
        
        if timesteps_since_eval >= eval_freq:
            timesteps_since_eval %=  eval_freq
            evaluation.append(evaluate(policy))
            policy.save(file_name, directory='/content/drive/MyDrive/DRL/models')
            np.save('/content/drive/MyDrive/DRL/results/%s'%(file_name), evaluation)

        obs = env.reset()
        done = False

        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    #Before 10000 timesteps,we play Random actions.
    if total_timesteps < start_timesteps:
        action = env.action_space.sample()
    else:#after 10000 we switch to the policy/model/agent
        action = policy.get_action(np.array(obs))
        if expi_noise != 0:
            action = (action + np.random.normal(0, expi_noise, size=env.action_space.shape[0])).clip(env.action_space.low,env.action_space.high)

    new_obs, reward, done, _ = env.step(action)

    done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)

    episode_reward += reward
    
    Memory.add((obs, new_obs, action, reward, done_bool))

    obs = new_obs
    episode_timesteps += 1
    total_timesteps += 1
    timesteps_since_eval += 1

evaluation.append(evaluate(policy))
if save_model:
    policy.save('%s'% (file_name), directory='/content/drive/MyDrive/DRL/models')
np.save("/content/drive/MyDrive/DRL/results/%s" % (file_name),evaluation)
# Out:
# Total timesteps:16 - Episode:1 - Reward:29.05637608106626
# Total timesteps:24 - Episode:2 - Reward:20.01591295011167
# Total timesteps:34 - Episode:3 - Reward:22.036458671405853
# Total timesteps:51 - Episode:4 - Reward:19.803455461015982
# Total timesteps:69 - Episode:5 - Reward:17.453622058752806
# Total timesteps:81 - Episode:6 - Reward:19.276845316313846
# Total timesteps:86 - Episode:7 - Reward:16.78463421813067
# Total timesteps:94 - Episode:8 - Reward:18.264891544888087
# Total timesteps:107 - Episode:9 - Reward:13.484286775598592
# Total timesteps:116 - Episode:10 - Reward:20.494939125757078
# Total timesteps:127 - Episode:11 - Reward:18.623737723080556
# Total timesteps:134 - Episode:12 - Reward:19.33823231160495
# Total timesteps:141 - Episode:13 - Reward:17.92542426261498
# Total timesteps:149 - Episode:14 - Reward:17.802375661052064
# Total timesteps:163 - Episode:15 - Reward:21.727406111369785
# Total timesteps:169 - Episode:16 - Reward:17.151570225146134
# Total timesteps:176 - Episode:17 - Reward:16.812281094075296
# Total timesteps:183 - Episode:18 - Reward:20.285609758367354
# Total timesteps:191 - Episode:19 - Reward:18.702979061809312
# Total timesteps:203 - Episode:20 - Reward:22.426731166151875
# Total timesteps:210 - Episode:21 - Reward:17.139445260184583
# Total timesteps:222 - Episode:22 - Reward:20.230036818177904
# Total timesteps:232 - Episode:23 - Reward:19.297028208019032
# Total timesteps:249 - Episode:24 - Reward:23.65555127156258
# Total timesteps:256 - Episode:25 - Reward:17.35764991800388
# Total timesteps:271 - Episode:26 - Reward:21.080075717531148
# Total timesteps:285 - Episode:27 - Reward:17.267574243180572
# Total timesteps:299 - Episode:28 - Reward:18.263447726183216
# Total timesteps:305 - Episode:29 - Reward:17.861534068270704
# Total timesteps:318 - Episode:30 - Reward:20.40373978285352
# Total timesteps:333 - Episode:31 - Reward:21.484462595227523
# Total timesteps:350 - Episode:32 - Reward:21.945040989445985
# Total timesteps:363 - Episode:33 - Reward:18.481008225172996
# Total timesteps:378 - Episode:34 - Reward:17.840597107469513
# Total timesteps:389 - Episode:35 - Reward:19.718134954557176
# Total timesteps:398 - Episode:36 - Reward:22.004241092977463
# Total timesteps:3988 - Episode:340 - Reward:26.335915735628802
# Total timesteps:4005 - Episode:341 - Reward:19.137001132137083
# Total timesteps:4010 - Episode:342 - Reward:17.458401406403574
# Total timesteps:4022 - Episode:343 - Reward:22.01549558658153
# Total timesteps:4036 - Episode:344 - Reward:19.26790441244375
# Total timesteps:4047 - Episode:345 - Reward:19.563887931643695
# Total timesteps:4060 - Episode:346 - Reward:21.65097517175018
# Total timesteps:4069 - Episode:347 - Reward:20.176588982366958
# Total timesteps:4075 - Episode:348 - Reward:19.106783213053134
# Total timesteps:4087 - Episode:349 - Reward:23.099379765466438
# Total timesteps:4096 - Episode:350 - Reward:20.443991369221475
# Total timesteps:4103 - Episode:351 - Reward:18.30736375543056
# Total timesteps:4116 - Episode:352 - Reward:23.753326485586875
# Total timesteps:4127 - Episode:353 - Reward:19.89463732304284
# Total timesteps:4138 - Episode:354 - Reward:19.74544935958984
# Total timesteps:4144 - Episode:355 - Reward:16.583621105119526
# Total timesteps:4151 - Episode:356 - Reward:18.774584724442686
# Total timesteps:4165 - Episode:357 - Reward:19.080841353644786
# Total timesteps:4173 - Episode:358 - Reward:21.5394345874578
# Total timesteps:4182 - Episode:359 - Reward:19.299114355760683
# Total timesteps:4193 - Episode:360 - Reward:19.291155297844668
# Total timesteps:4208 - Episode:361 - Reward:25.055584787850968
# Total timesteps:4225 - Episode:362 - Reward:24.077675030521636
# Total timesteps:4236 - Episode:363 - Reward:20.3769542720227
# Total timesteps:4252 - Episode:364 - Reward:23.839054993093303
# Total timesteps:4264 - Episode:365 - Reward:17.542632164763926
# Total timesteps:4283 - Episode:366 - Reward:24.062390304676956
# Total timesteps:4299 - Episode:367 - Reward:25.60432539993781
# Total timesteps:4307 - Episode:368 - Reward:16.108150163196843
# Total timesteps:4325 - Episode:369 - Reward:23.046208284171012
# Total timesteps:4330 - Episode:370 - Reward:16.541698341481972
# Total timesteps:4342 - Episode:371 - Reward:20.661332130666413
# Total timesteps:4359 - Episode:372 - Reward:25.348205273448546
# Total timesteps:4370 - Episode:373 - Reward:23.120258728602494
# Total timesteps:4379 - Episode:374 - Reward:17.43332559363189
# Total timesteps:4392 - Episode:375 - Reward:20.465159618754114
# Total timesteps:4400 - Episode:376 - Reward:20.542355086051973
# Total timesteps:4410 - Episode:377 - Reward:16.65312406618177
# Total timesteps:4421 - Episode:378 - Reward:20.82205447349261
# Total timesteps:4431 - Episode:379 - Reward:17.764150135834644
# Total timesteps:4443 - Episode:380 - Reward:21.4332082518813
# Total timesteps:4453 - Episode:381 - Reward:17.585307569339054
# Total timesteps:4462 - Episode:382 - Reward:17.599497398256794
# Total timesteps:4475 - Episode:383 - Reward:20.802806984804917
# Total timesteps:4483 - Episode:384 - Reward:19.06369159197493
# Total timesteps:4506 - Episode:385 - Reward:25.20245189657288
# Total timesteps:4520 - Episode:386 - Reward:23.748590254451848
# Total timesteps:4527 - Episode:387 - Reward:20.612166040517334
# Total timesteps:4534 - Episode:388 - Reward:17.538429334039392
# Total timesteps:4546 - Episode:389 - Reward:20.45109236664866
# Total timesteps:4556 - Episode:390 - Reward:20.451881476338894
# Total timesteps:4566 - Episode:391 - Reward:19.786186298265235
# Total timesteps:4580 - Episode:392 - Reward:17.712069613393396
# Total timesteps:4586 - Episode:393 - Reward:17.927434712753165
# Total timesteps:4605 - Episode:394 - Reward:22.18219892628258
# Total timesteps:4620 - Episode:395 - Reward:22.96898926133435
# Total timesteps:4630 - Episode:396 - Reward:18.873366170667577
# Total timesteps:4639 - Episode:397 - Reward:17.100904330592314
# Total timesteps:4646 - Episode:398 - Reward:15.973196317278777
# Total timesteps:4658 - Episode:399 - Reward:19.654535094597666
# Total timesteps:4672 - Episode:400 - Reward:22.919411856500666
# Total timesteps:4681 - Episode:401 - Reward:18.80177847055311
# Total timesteps:4687 - Episode:402 - Reward:18.506775666089382
# Total timesteps:4694 - Episode:403 - Reward:18.12861163446214
# Total timesteps:4710 - Episode:404 - Reward:22.981447235296947
# Total timesteps:4717 - Episode:405 - Reward:17.58812942965742
# Total timesteps:4730 - Episode:406 - Reward:20.997507213268545
# Total timesteps:4739 - Episode:407 - Reward:18.699579595803517
# Total timesteps:4748 - Episode:408 - Reward:21.504836460968363
# Total timesteps:4772 - Episode:409 - Reward:25.55694937860099
# Total timesteps:4779 - Episode:410 - Reward:18.099965090019396
# Total timesteps:4784 - Episode:411 - Reward:16.049314874045375
# Total timesteps:4804 - Episode:412 - Reward:20.970751643652328
# Total timesteps:4816 - Episode:413 - Reward:20.653126697476548
# Total timesteps:4845 - Episode:414 - Reward:25.594332653806486
# Total timesteps:4854 - Episode:415 - Reward:17.52204794924619
# Total timesteps:4863 - Episode:416 - Reward:18.705657513004553
# Total timesteps:4871 - Episode:417 - Reward:19.33677207977162
# Total timesteps:4882 - Episode:418 - Reward:18.88194418088533
# Total timesteps:4889 - Episode:419 - Reward:16.20493028797064
# Total timesteps:4898 - Episode:420 - Reward:19.710904296494846
# Total timesteps:4920 - Episode:421 - Reward:18.850920023462095
# Total timesteps:4928 - Episode:422 - Reward:19.01227429773717
# Total timesteps:4937 - Episode:423 - Reward:20.4406170004615
# Total timesteps:4947 - Episode:424 - Reward:20.045909842127003
# Total timesteps:4960 - Episode:425 - Reward:21.659763852584
# Total timesteps:4971 - Episode:426 - Reward:19.096606516103204
# Total timesteps:4983 - Episode:427 - Reward:21.638538686574613
# Total timesteps:4989 - Episode:428 - Reward:16.5313628007556
# Total timesteps:5001 - Episode:429 - Reward:20.370033742340453
# Average award over 10 is: 67.52706992464141
# Total timesteps:5014 - Episode:430 - Reward:20.990472018759466
# Total timesteps:5024 - Episode:431 - Reward:20.402438896067906
# Total timesteps:5032 - Episode:432 - Reward:17.078053815719613
# Total timesteps:5046 - Episode:433 - Reward:16.658087135174718
# Total timesteps:5070 - Episode:434 - Reward:14.847143282150498
# Total timesteps:5083 - Episode:435 - Reward:21.386913772605475
# Total timesteps:5097 - Episode:436 - Reward:23.178460996305507
# Total timesteps:5102 - Episode:437 - Reward:15.677293130940233
# Total timesteps:5113 - Episode:438 - Reward:19.169478739619084
# Total timesteps:5127 - Episode:439 - Reward:21.34990185989736
# Total timesteps:8015 - Episode:690 - Reward:19.811769079005174
# Total timesteps:8024 - Episode:691 - Reward:19.734797426557638
# Total timesteps:8034 - Episode:692 - Reward:18.346523498751047
# Total timesteps:8042 - Episode:693 - Reward:20.5220864879564
# Total timesteps:8055 - Episode:694 - Reward:20.403802846393955
# Total timesteps:8061 - Episode:695 - Reward:17.19462824925431
# Total timesteps:8078 - Episode:696 - Reward:28.00415788076498
# Total timesteps:8085 - Episode:697 - Reward:17.38353479478974
# Total timesteps:8100 - Episode:698 - Reward:25.31781540155061
# Total timesteps:8121 - Episode:699 - Reward:23.36545010729897
# Total timesteps:8137 - Episode:700 - Reward:24.28260163428349
# Total timesteps:8152 - Episode:701 - Reward:20.647285194440336
# Total timesteps:8168 - Episode:702 - Reward:16.29932034119556
# Total timesteps:8185 - Episode:703 - Reward:18.902598009993376
# Total timesteps:8205 - Episode:704 - Reward:21.797918517555804
# Total timesteps:8213 - Episode:705 - Reward:21.701475810434204
# Total timesteps:8221 - Episode:706 - Reward:17.41411186970217
# Total timesteps:8245 - Episode:707 - Reward:26.803869262256196
# Total timesteps:8255 - Episode:708 - Reward:23.299055116235106
# Total timesteps:8266 - Episode:709 - Reward:21.12682251845399
# Total timesteps:8276 - Episode:710 - Reward:20.981014952108676
# Total timesteps:8286 - Episode:711 - Reward:23.237980502705614
# Total timesteps:8293 - Episode:712 - Reward:16.147638852917588
# Total timesteps:8307 - Episode:713 - Reward:23.981711514352355
# Total timesteps:8315 - Episode:714 - Reward:17.69341391685157
# Total timesteps:8326 - Episode:715 - Reward:20.579169322911188
# Total timesteps:8334 - Episode:716 - Reward:19.581764954561372
# Total timesteps:8342 - Episode:717 - Reward:21.013621344450804
# Total timesteps:8347 - Episode:718 - Reward:16.92670688135695
# Total timesteps:8360 - Episode:719 - Reward:17.198157813746366
# Total timesteps:8367 - Episode:720 - Reward:16.07816377831914
# Total timesteps:8380 - Episode:721 - Reward:22.90731709545362
# Total timesteps:8390 - Episode:722 - Reward:18.29649300112069
# Total timesteps:8407 - Episode:723 - Reward:19.854114875233787
# Total timesteps:8420 - Episode:724 - Reward:19.802017121163953
# Total timesteps:8432 - Episode:725 - Reward:12.512645835019066
# Total timesteps:8442 - Episode:726 - Reward:19.002727831790978
# Total timesteps:8459 - Episode:727 - Reward:16.87780896775657
# Total timesteps:8474 - Episode:728 - Reward:19.550269422786368
# Total timesteps:8488 - Episode:729 - Reward:19.61987612996599
# Total timesteps:8503 - Episode:730 - Reward:16.357124968634164
# Total timesteps:8517 - Episode:731 - Reward:20.083196473300628
# Total timesteps:8528 - Episode:732 - Reward:19.425283863073854
# Total timesteps:8537 - Episode:733 - Reward:20.256744415593854
# Total timesteps:8547 - Episode:734 - Reward:18.614779747829015
# Total timesteps:8573 - Episode:735 - Reward:29.36382774705125
# Total timesteps:8579 - Episode:736 - Reward:18.44929060410213
# Total timesteps:8586 - Episode:737 - Reward:18.915135426442433
# Total timesteps:8600 - Episode:738 - Reward:21.587806649072444
# Total timesteps:8608 - Episode:739 - Reward:17.95512045593059
# Total timesteps:8617 - Episode:740 - Reward:16.13734856045485
# Total timesteps:8627 - Episode:741 - Reward:20.428250535455298
# Total timesteps:8638 - Episode:742 - Reward:23.194590098802294
# Total timesteps:8655 - Episode:743 - Reward:25.128887165761263
# Total timesteps:8667 - Episode:744 - Reward:17.511779865418795
# Total timesteps:8676 - Episode:745 - Reward:20.31282412419969
# Total timesteps:8694 - Episode:746 - Reward:22.164300903231194
# Total timesteps:8714 - Episode:747 - Reward:22.929997766428276
# Total timesteps:8726 - Episode:748 - Reward:17.66317074159888
# Total timesteps:8737 - Episode:749 - Reward:19.827754944743354
# Total timesteps:8748 - Episode:750 - Reward:20.505676587464404
# Total timesteps:8756 - Episode:751 - Reward:20.14775111215276
# Total timesteps:8762 - Episode:752 - Reward:18.50453170106048
# Total timesteps:8771 - Episode:753 - Reward:19.243511995377776
# Total timesteps:8778 - Episode:754 - Reward:18.67881520652736
# Total timesteps:8793 - Episode:755 - Reward:22.132522558896742
# Total timesteps:8802 - Episode:756 - Reward:22.03863835807424
# Total timesteps:8810 - Episode:757 - Reward:16.192864463194564
# Total timesteps:8834 - Episode:758 - Reward:31.78840899018978
# Total timesteps:8852 - Episode:759 - Reward:23.88731294569152
# Total timesteps:8858 - Episode:760 - Reward:16.07829735590494
# Total timesteps:8868 - Episode:761 - Reward:21.296589457195658
# Total timesteps:8877 - Episode:762 - Reward:18.683812533528545
# Total timesteps:8886 - Episode:763 - Reward:17.95371164950193
# Total timesteps:8903 - Episode:764 - Reward:28.14186093692406
# Total timesteps:8911 - Episode:765 - Reward:17.572985031049758
# Total timesteps:8924 - Episode:766 - Reward:14.436469064562699
# Total timesteps:8931 - Episode:767 - Reward:18.753036157088356
# Total timesteps:8944 - Episode:768 - Reward:18.695433037049952
# Total timesteps:8966 - Episode:769 - Reward:25.867101738550993
# Total timesteps:8976 - Episode:770 - Reward:18.692571161614616
# Total timesteps:8987 - Episode:771 - Reward:20.50278878659883
# Total timesteps:8996 - Episode:772 - Reward:16.88210220208566
# Total timesteps:9009 - Episode:773 - Reward:19.552672325655294
# Total timesteps:9032 - Episode:774 - Reward:22.997944096407448
# Total timesteps:9056 - Episode:775 - Reward:21.75195422955294
# Total timesteps:9061 - Episode:776 - Reward:16.870890533692727
# Total timesteps:9067 - Episode:777 - Reward:17.353449645190267
# Total timesteps:9089 - Episode:778 - Reward:21.924275371097615
# Total timesteps:9104 - Episode:779 - Reward:24.386412068123175
# Total timesteps:9114 - Episode:780 - Reward:16.496769590974147
# Total timesteps:9123 - Episode:781 - Reward:17.082450006945876
# Total timesteps:9136 - Episode:782 - Reward:22.86020207155816
# Total timesteps:9146 - Episode:783 - Reward:19.200533314145286
# Total timesteps:9152 - Episode:784 - Reward:18.874960814176305
# Total timesteps:9160 - Episode:785 - Reward:19.175147776529776
# Total timesteps:9176 - Episode:786 - Reward:26.906534290364654
# Total timesteps:9190 - Episode:787 - Reward:22.930596301892365
# Total timesteps:9200 - Episode:788 - Reward:19.105037789410563
# Total timesteps:9221 - Episode:789 - Reward:24.317763291788285
# Total timesteps:9227 - Episode:790 - Reward:17.468860681325896
# Total timesteps:9235 - Episode:791 - Reward:18.211381294946477
# Total timesteps:9253 - Episode:792 - Reward:25.02898213085282
# Total timesteps:9271 - Episode:793 - Reward:21.219398251097303
# Total timesteps:9285 - Episode:794 - Reward:20.195790422060238
# Total timesteps:9298 - Episode:795 - Reward:22.23158546269988
# Total timesteps:9313 - Episode:796 - Reward:20.228705482451186
# Total timesteps:9318 - Episode:797 - Reward:16.26719796774705
# Total timesteps:9332 - Episode:798 - Reward:19.1594300658704
# Total timesteps:9341 - Episode:799 - Reward:20.69824479955278
# Total timesteps:9358 - Episode:800 - Reward:23.753070568742988
# Total timesteps:9371 - Episode:801 - Reward:23.52822495959845
# Total timesteps:9385 - Episode:802 - Reward:20.013981385376244
# Total timesteps:9394 - Episode:803 - Reward:20.6574156184317
# Total timesteps:9408 - Episode:804 - Reward:22.3861314842492
# Total timesteps:9417 - Episode:805 - Reward:21.796634505463587
# Total timesteps:9429 - Episode:806 - Reward:20.94409962872887
# Total timesteps:9440 - Episode:807 - Reward:20.3099011154889
# Total timesteps:9455 - Episode:808 - Reward:12.050478027676581
# Total timesteps:9465 - Episode:809 - Reward:21.286291605554286
# Total timesteps:9478 - Episode:810 - Reward:18.53677949484845
# Total timesteps:9485 - Episode:811 - Reward:19.036942088986688
# Total timesteps:9495 - Episode:812 - Reward:20.035449249610245
# Total timesteps:9511 - Episode:813 - Reward:20.85478078959568
# Total timesteps:9524 - Episode:814 - Reward:21.943933098721025
# Total timesteps:9543 - Episode:815 - Reward:20.134612915638716
# Total timesteps:9552 - Episode:816 - Reward:21.817463507025966
# Total timesteps:9559 - Episode:817 - Reward:17.15642088770692
# Total timesteps:9568 - Episode:818 - Reward:19.300089958026362
# Total timesteps:9579 - Episode:819 - Reward:19.721193109161685
# Total timesteps:9592 - Episode:820 - Reward:22.62336415285681
# Total timesteps:9601 - Episode:821 - Reward:20.691186148967244
# Total timesteps:9610 - Episode:822 - Reward:20.152967349420944
# Total timesteps:9621 - Episode:823 - Reward:21.026956363370118
# Total timesteps:9631 - Episode:824 - Reward:21.474079233834345
# Total timesteps:9650 - Episode:825 - Reward:23.18472923012159
# Total timesteps:9661 - Episode:826 - Reward:20.60306228996778
# Total timesteps:9672 - Episode:827 - Reward:22.512371841633286
# Total timesteps:9681 - Episode:828 - Reward:23.087702852654907
# Total timesteps:9698 - Episode:829 - Reward:18.92515827981115
# Total timesteps:9705 - Episode:830 - Reward:16.306048443190228
# Total timesteps:9722 - Episode:831 - Reward:23.544283322282716
# Total timesteps:9729 - Episode:832 - Reward:20.43825973148487
# Total timesteps:9744 - Episode:833 - Reward:22.508733678991845
# Total timesteps:9750 - Episode:834 - Reward:17.762551631186213
# Total timesteps:9757 - Episode:835 - Reward:17.615232261565687
# Total timesteps:9772 - Episode:836 - Reward:19.2071288298961
# Total timesteps:9785 - Episode:837 - Reward:17.748517596076997
# Total timesteps:9796 - Episode:838 - Reward:19.497547158894303
# Total timesteps:9809 - Episode:839 - Reward:20.018778306344757
# Total timesteps:9822 - Episode:840 - Reward:20.508234855240154
# Total timesteps:9844 - Episode:841 - Reward:28.11784753732354
# Total timesteps:9857 - Episode:842 - Reward:21.679193607669735
# Total timesteps:9863 - Episode:843 - Reward:17.150759787198332
# Total timesteps:9874 - Episode:844 - Reward:13.766550613431901
# Total timesteps:9888 - Episode:845 - Reward:24.394116335749274
# Total timesteps:9899 - Episode:846 - Reward:18.23122507441003
# Total timesteps:9907 - Episode:847 - Reward:21.586537131175284
# Total timesteps:9927 - Episode:848 - Reward:29.47770488198148
# Total timesteps:9941 - Episode:849 - Reward:23.02813734438532
# Total timesteps:9958 - Episode:850 - Reward:19.743524964884273
# Total timesteps:9965 - Episode:851 - Reward:21.144833225454203
# Total timesteps:9975 - Episode:852 - Reward:20.37795526646951
# Total timesteps:9985 - Episode:853 - Reward:18.03245896899171
# Total timesteps:9994 - Episode:854 - Reward:17.999290574966288
# Total timesteps:10001 - Episode:855 - Reward:17.808610566830325
# Average award over 10 is: 94.6032828380403
# Total timesteps:10068 - Episode:856 - Reward:90.71858589413428
# Total timesteps:11068 - Episode:857 - Reward:801.8446874661106
# Total timesteps:12068 - Episode:858 - Reward:777.6589097832426
# Total timesteps:12121 - Episode:859 - Reward:67.90171080381198
# Total timesteps:12191 - Episode:860 - Reward:85.72229087979856
# Total timesteps:12257 - Episode:861 - Reward:78.97583453765628
# Total timesteps:12339 - Episode:862 - Reward:117.05556004570349
# Total timesteps:12410 - Episode:863 - Reward:84.53556143796183
# Total timesteps:12490 - Episode:864 - Reward:86.6590320520243
# Total timesteps:13490 - Episode:865 - Reward:870.717170022475
# Total timesteps:13531 - Episode:866 - Reward:39.96940162035886
# Total timesteps:13568 - Episode:867 - Reward:36.03071432617792
# Total timesteps:13609 - Episode:868 - Reward:43.4970649628161
# Total timesteps:13656 - Episode:869 - Reward:53.2227914248315
# Total timesteps:13694 - Episode:870 - Reward:44.071928361454795
# Total timesteps:13733 - Episode:871 - Reward:44.57966643371435
# Total timesteps:13782 - Episode:872 - Reward:48.509777194437255
# Total timesteps:13824 - Episode:873 - Reward:43.989539070230705
# Total timesteps:13876 - Episode:874 - Reward:54.430834764911886
# Total timesteps:14876 - Episode:875 - Reward:910.3906931660891
# Total timesteps:14934 - Episode:876 - Reward:63.225355837285804
# Total timesteps:14997 - Episode:877 - Reward:76.8750765745981
# Average award over 10 is: 81.78696513732345

# %% [markdown]
# ### **Visualizing  by testing**

# %%
env_name = 'HopperBulletEnv-v0'
seed = 0

file_name = f"MODEL_DRL--{env_name}--seed({seed})"
print(file_name)

eval_episodes = 10

env = gym.make(env_name)
max_episode_step = env._max_episode_steps

env = wrappers.Monitor(env, '/content/drive/MyDrive/DRL/exp/vids/', force=True)
env.reset()
#setting env
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
#agent
policy = MODEL_DRL(state_dim, action_dim, max_action)
policy.load(file_name, "/content/drive/MyDrive/DRL/models")
_ = evaluate(policy, episodes=eval_episodes)
# Out:
# MODEL_DRL--HopperBulletEnv-v0--seed(0)
# Average award over 10 is: 83.35262543137912

# %%
print('Done')
# Out:
# Done

# %% [markdown]
# ## **The End**
